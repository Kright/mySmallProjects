# %% [raw]
# # Idea:
# Compare Leaky ReLU and it's variations
#
# # Result
#
# Suprisingly, convolution network with mnist task is working better with GA2 elements in terms of `accuracy / trainable parameters ratio`

# %%
import time
from typing import Optional, Tuple, List

import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
from torch.autograd import Variable
from torch.utils.data import DataLoader

from myutil import Bias, GA2Mag

# %%
torch.__version__
# Out:
# '2.0.1+cu117'

# %%
from torchvision import datasets
from torchvision.transforms import ToTensor

train_data = datasets.MNIST(
    root='models/mnist',
    train=True,
    transform=ToTensor(),
    download=True,
)

test_data = datasets.MNIST(
    root='models/mnist',
    train=False,
    transform=ToTensor(),
    download=True,
)

# %%
class TrainHelper:
    @staticmethod
    def train(cnn: nn.Module,
              *,
              epochs: int,
              train_dataset: datasets.MNIST,
              test_dataset: Optional[datasets.MNIST] = None,
              print_results: bool = True,
              batch_size: int,
              device_name: str) -> List[float]:

        train_loader = torch.utils.data.DataLoader(train_dataset,
                                                   batch_size=batch_size,
                                                   shuffle=True,
                                                   num_workers=1)

        device = torch.device(device_name)

        cnn.to(device)
        cnn.train()

        optimizer = torch.optim.Adam(cnn.parameters(), lr=0.001)
        loss_func = nn.CrossEntropyLoss()

        eval_results: List[float] = []

        for epoch in range(epochs):
            for images, labels in train_loader:
                images = Variable(images.to(device))
                labels = Variable(labels.to(device))

                output = cnn(images)
                loss = loss_func(output, labels)

                optimizer.zero_grad()
                loss.backward()
                optimizer.step()

            if test_dataset is not None:
                eval_result = TrainHelper.test(cnn, test_dataset, device)
                eval_results.append(eval_result)
                if print_results:
                    print(f"epoch {epoch}, accuracy = {eval_result}, loss = {loss.detach()}")
                cnn.train()

        return eval_results

    @staticmethod
    def test(cnn: nn.Module, test_dataset: datasets.MNIST, device=None) -> float:
        cnn.eval()
        loader = torch.utils.data.DataLoader(test_dataset, batch_size=128, shuffle=False, num_workers=1)
        correct = 0
        incorrect = 0

        for images, labels in loader:
            if device is not None:
                images = images.to(device)

            results = cnn(images)
            predictions = results.detach().cpu().numpy().argmax(axis=1)
            oks = (predictions == labels.numpy()).sum()
            correct += oks
            incorrect += len(predictions) - oks

        return correct / (correct + incorrect)

    @staticmethod
    def train_models(models: List[nn.Module], device_name: str) -> Tuple[int, float]:
        """
        generator yields pair (trainable parameters count, best accuracy) for each network
        :param device_name: 'cuda' or 'cpu'
        """
        assert len(models) > 0

        for model in models:
            start = time.time()
            eval_results = TrainHelper.train(
                cnn=model,
                epochs=20,
                train_dataset=train_data,
                test_dataset=test_data,
                batch_size=2048,
                device_name=device_name,
                print_results=False
            )
            end = time.time()
            best_acc = max(eval_results)
            params_count = TrainHelper.total_parameters_count(model)
            print(f"best accuracy = {best_acc}, parameters = {params_count}, training time = {end - start}")
            yield params_count, best_acc

    @staticmethod
    def total_parameters_count(model: nn.Module) -> int:
        return sum(np.prod(p.size()) for p in model.parameters())

    @staticmethod
    def print_parameters(model: nn.Module):
        print(f"total parameters = {TrainHelper.total_parameters_count(model)}")
        for p in model.parameters():
            print(f"size {np.prod(p.size())}: {p.size()}")

# %%
class GA2Conv2d(nn.Module):
    """
    no bias!
    GA(2, 0, 1), so it has x, y where xx = 1, yy = 1
    """

    def __init__(self, in_ch_ga2: int, out_ch_ga2: int, *, kernel_size: int):
        super(GA2Conv2d, self).__init__()
        self.in_ch = in_ch_ga2
        self.out_ch = out_ch_ga2
        self.convs = nn.ParameterList(
            [nn.Conv2d(self.in_ch, self.out_ch, bias=False, stride=1, kernel_size=kernel_size, padding='valid') for _ in
             range(4)]
        )

    def forward(self, x):
        assert x.size()[1] == self.in_ch * 4

        ch = self.in_ch
        s, x, y, xy = x[:, :ch], x[:, ch:2 * ch], x[:, 2 * ch:3 * ch], x[:, 3 * ch:4 * ch]

        c_s, c_x, c_y, c_xy = self.convs

        # (a + b x + c y + d xy) (e + f x + g y + h xy) == 
        # (ae + bf + cg + dh) + (af + be - ch + dg)x + (ag + bh + ce - df)y + (ah + bg - cf + de)xy

        # a => c_s, b => c_x, c => c_y, d => c_xy
        # e => s, f => x, g => y, h => xy 

        out_lst = [
            c_s(s) + c_x(x) + c_y(y) + c_xy(xy),
            c_s(x) + c_x(s) - c_y(xy) + c_xy(y),
            c_s(y) + c_x(xy) + c_y(s) - c_xy(x),
            c_s(xy) + c_x(y) - c_y(x) + c_xy(s),
        ]

        return torch.cat(out_lst, dim=1)


class GA2ReLU(nn.Module):
    def __init__(self, in_ch_ga2: int):
        super(GA2ReLU, self).__init__()
        self.in_ch = in_ch_ga2
        self.mults = nn.ParameterList([torch.ones(size=(1, in_ch_ga2, 1, 1)) for _ in range(4)])

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        assert x.size()[1] == self.in_ch * 4

        ch = self.in_ch
        s, x, y, xy = [x[:, i * ch: i * ch + ch] for i in range(4)]
        p_s, p_x, p_y, p_xy = self.mults
        mag = (p_s ** 2 + p_x ** 2 + p_y ** 2 + p_xy ** 2 + 1e-9) ** 0.5

        weights = (s * p_s + x * p_x + y * p_y + xy * p_xy) / mag
        # weights = s + x + y + xy
        weights = (weights > 0.0).float() * 0.9 + 0.1

        return torch.cat([s * weights, x * weights, y * weights, xy * weights], dim=1)

# %%
class MyConvModel(nn.Module):
    def __init__(self, channels: int, mode: str):
        super(MyConvModel, self).__init__()
        self.channels = channels
        self.mode = mode

        c = channels
        self.conv1 = self.conv(1, c, kernel_size=3)  # 28 - 26
        self.conv2 = self.conv(c, c, kernel_size=3, max_pool=2)  # 26 - 24 - 12
        self.conv3 = self.conv(c, c * 2, kernel_size=3)  # 12 - 10
        self.conv4 = self.conv(c * 2, c * 2, kernel_size=3, max_pool=2)  # 10 - 8 - 4
        self.conv5 = self.conv(c * 2, c * 4, kernel_size=3)  # 4 - 2
        self.conv6 = self.conv(c * 4, c * 4, kernel_size=2)  # 2 - 1
        self.conv7 = self.conv(c * 4, 10, kernel_size=1, use_activation=False)
        self.to_real: Optional[nn.Module] = GA2Mag()
        self.flatten = nn.Flatten()

    def conv(self, in_ch: int, out_ch: int, *, kernel_size, max_pool: int = 1, use_activation: bool = True):
        layers: List[nn.Module] = []

        layers.append(GA2Conv2d(in_ch, out_ch, kernel_size=kernel_size))
        layers.append(Bias(out_ch * 4))

        if use_activation:
            if self.mode == 'naive':
                layers.append(nn.LeakyReLU(0.1))
            elif self.mode == 'ga2':
                layers.append(GA2ReLU(out_ch))
            else: 
                NameError(f"wrong mode: {self.mode}")
        
        if max_pool != 1:
            layers.append(nn.MaxPool2d(kernel_size=max_pool))
            
        return nn.Sequential(*layers)

    def forward(self, x: torch.Tensor):
        x = torch.cat([x, x * 0.0, x * 0.0, x * 0.0], dim=1)  # convert to ga2
        x = self.conv1(x)
        x = self.conv2(x)
        x = self.conv3(x)
        x = self.conv4(x)
        x = self.conv5(x)
        x = self.conv6(x)
        x = self.conv7(x)
        if self.to_real is not None:
            x = self.to_real(x)
        x = self.flatten(x)
        return x

# %%
modes = ['ga2', 'naive']
channel_multipliers = [4, 6, 8, 12, 16, 24, 32]
results = {mode: [] for mode in modes}

# %% [markdown]
# ## Cell below could be executed several times to get more points

# %%
for i in range(8):
    for mode in modes:
        models = [MyConvModel(n, mode=mode) for n in channel_multipliers]
        for pair in TrainHelper.train_models(models, device_name='cuda'):
            results[mode].append(pair)
# Out:
# best accuracy = 0.9841, parameters = 14008, training time = 97.11750054359436
# best accuracy = 0.9872, parameters = 30544, training time = 96.86958956718445
# best accuracy = 0.9884, parameters = 53448, training time = 97.35333824157715
# best accuracy = 0.9911, parameters = 118360, training time = 132.14398956298828
# best accuracy = 0.9917, parameters = 208744, training time = 213.2624123096466
# best accuracy = 0.9912, parameters = 465928, training time = 313.65181589126587
# best accuracy = 0.9924, parameters = 825000, training time = 400.49712562561035
# best accuracy = 0.9821, parameters = 13784, training time = 97.25218224525452
# best accuracy = 0.986, parameters = 30208, training time = 97.94362902641296
# best accuracy = 0.9889, parameters = 53000, training time = 98.62236499786377
# best accuracy = 0.9905, parameters = 117688, training time = 115.01318573951721
# best accuracy = 0.9916, parameters = 207848, training time = 185.78449892997742
# best accuracy = 0.9936, parameters = 464584, training time = 262.9510853290558
# best accuracy = 0.9936, parameters = 823208, training time = 321.55904722213745
# best accuracy = 0.9821, parameters = 14008, training time = 97.24586868286133
# best accuracy = 0.9874, parameters = 30544, training time = 97.86694836616516
# best accuracy = 0.9889, parameters = 53448, training time = 98.22938299179077
# best accuracy = 0.9911, parameters = 118360, training time = 128.98230051994324
# best accuracy = 0.9909, parameters = 208744, training time = 202.1183476448059
# best accuracy = 0.9922, parameters = 465928, training time = 289.02502512931824
# best accuracy = 0.9933, parameters = 825000, training time = 368.92639780044556
# best accuracy = 0.9835, parameters = 13784, training time = 96.8003876209259
# best accuracy = 0.9859, parameters = 30208, training time = 97.02159214019775
# best accuracy = 0.9897, parameters = 53000, training time = 97.41442489624023
# best accuracy = 0.992, parameters = 117688, training time = 107.62056946754456
# best accuracy = 0.9922, parameters = 207848, training time = 172.80321502685547
# best accuracy = 0.9916, parameters = 464584, training time = 244.61676025390625
# best accuracy = 0.994, parameters = 823208, training time = 308.76862931251526
# best accuracy = 0.9818, parameters = 14008, training time = 97.46369194984436
# best accuracy = 0.9868, parameters = 30544, training time = 97.76037788391113
# best accuracy = 0.9885, parameters = 53448, training time = 97.96158742904663
# best accuracy = 0.9898, parameters = 118360, training time = 128.883465051651
# best accuracy = 0.992, parameters = 208744, training time = 201.90320491790771
# best accuracy = 0.9914, parameters = 465928, training time = 289.1279351711273
# best accuracy = 0.9923, parameters = 825000, training time = 368.97411155700684
# best accuracy = 0.9812, parameters = 13784, training time = 97.06133913993835
# best accuracy = 0.9882, parameters = 30208, training time = 97.35913372039795
# best accuracy = 0.9896, parameters = 53000, training time = 97.41106581687927
# best accuracy = 0.9893, parameters = 117688, training time = 108.84664797782898
# best accuracy = 0.9907, parameters = 207848, training time = 172.78577613830566
# best accuracy = 0.9914, parameters = 464584, training time = 244.6202530860901
# best accuracy = 0.9936, parameters = 823208, training time = 310.33610463142395
# best accuracy = 0.9815, parameters = 14008, training time = 95.33669757843018
# best accuracy = 0.9889, parameters = 30544, training time = 95.97528791427612
# best accuracy = 0.99, parameters = 53448, training time = 96.91544032096863
# best accuracy = 0.9909, parameters = 118360, training time = 129.29096579551697
# best accuracy = 0.9904, parameters = 208744, training time = 202.03639483451843
# best accuracy = 0.9921, parameters = 465928, training time = 289.0187726020813
# best accuracy = 0.9936, parameters = 825000, training time = 368.8166790008545
# best accuracy = 0.9825, parameters = 13784, training time = 94.81481432914734
# best accuracy = 0.9878, parameters = 30208, training time = 95.33437919616699
# best accuracy = 0.99, parameters = 53000, training time = 95.63925814628601
# best accuracy = 0.9905, parameters = 117688, training time = 107.4135160446167
# best accuracy = 0.9919, parameters = 207848, training time = 172.27193880081177
# best accuracy = 0.9923, parameters = 464584, training time = 244.3045015335083
# best accuracy = 0.9927, parameters = 823208, training time = 308.9379150867462
# best accuracy = 0.9816, parameters = 14008, training time = 97.18659687042236
# best accuracy = 0.9878, parameters = 30544, training time = 97.3886501789093
# best accuracy = 0.9898, parameters = 53448, training time = 96.52990937232971
# best accuracy = 0.9888, parameters = 118360, training time = 129.13663530349731
# best accuracy = 0.9913, parameters = 208744, training time = 202.43528127670288
# best accuracy = 0.9917, parameters = 465928, training time = 289.0145535469055
# best accuracy = 0.9928, parameters = 825000, training time = 368.75298261642456
# best accuracy = 0.9827, parameters = 13784, training time = 96.56718301773071
# best accuracy = 0.9866, parameters = 30208, training time = 97.4104278087616
# best accuracy = 0.9896, parameters = 53000, training time = 97.81408739089966
# best accuracy = 0.9902, parameters = 117688, training time = 107.61389231681824
# best accuracy = 0.9913, parameters = 207848, training time = 172.81527304649353
# best accuracy = 0.9926, parameters = 464584, training time = 244.56310153007507
# best accuracy = 0.9936, parameters = 823208, training time = 309.00589394569397
# best accuracy = 0.9818, parameters = 14008, training time = 97.52945947647095
# best accuracy = 0.9886, parameters = 30544, training time = 97.46823287010193
# best accuracy = 0.9887, parameters = 53448, training time = 98.58061528205872
# best accuracy = 0.9889, parameters = 118360, training time = 129.37869596481323
# best accuracy = 0.9912, parameters = 208744, training time = 202.16313791275024
# best accuracy = 0.9923, parameters = 465928, training time = 289.0832598209381
# best accuracy = 0.9927, parameters = 825000, training time = 368.9533131122589
# best accuracy = 0.9825, parameters = 13784, training time = 96.84270787239075
# best accuracy = 0.9886, parameters = 30208, training time = 97.42540192604065
# best accuracy = 0.9906, parameters = 53000, training time = 98.03281903266907
# best accuracy = 0.9914, parameters = 117688, training time = 107.73164916038513
# best accuracy = 0.991, parameters = 207848, training time = 172.91352701187134
# best accuracy = 0.9929, parameters = 464584, training time = 244.76054978370667
# best accuracy = 0.9928, parameters = 823208, training time = 308.9108109474182
# best accuracy = 0.9822, parameters = 14008, training time = 97.58153820037842
# best accuracy = 0.9875, parameters = 30544, training time = 98.19592809677124
# best accuracy = 0.9899, parameters = 53448, training time = 98.7230315208435
# best accuracy = 0.9893, parameters = 118360, training time = 129.2020115852356
# best accuracy = 0.9902, parameters = 208744, training time = 201.99799180030823
# best accuracy = 0.9914, parameters = 465928, training time = 289.0554630756378
# best accuracy = 0.9932, parameters = 825000, training time = 369.0002727508545
# best accuracy = 0.9846, parameters = 13784, training time = 97.21796751022339
# best accuracy = 0.9881, parameters = 30208, training time = 97.12112164497375
# best accuracy = 0.9913, parameters = 53000, training time = 97.99454164505005
# best accuracy = 0.9908, parameters = 117688, training time = 107.9168450832367
# best accuracy = 0.9918, parameters = 207848, training time = 172.6117627620697
# best accuracy = 0.9927, parameters = 464584, training time = 244.68166422843933
# best accuracy = 0.9931, parameters = 823208, training time = 309.08228850364685
# best accuracy = 0.982, parameters = 14008, training time = 97.47549319267273
# best accuracy = 0.9883, parameters = 30544, training time = 98.21893548965454
# best accuracy = 0.9869, parameters = 53448, training time = 98.62205862998962
# best accuracy = 0.9904, parameters = 118360, training time = 129.78788447380066
# best accuracy = 0.9906, parameters = 208744, training time = 203.8073070049286
# best accuracy = 0.9914, parameters = 465928, training time = 290.8186993598938
# best accuracy = 0.9932, parameters = 825000, training time = 370.5541853904724
# best accuracy = 0.9868, parameters = 13784, training time = 95.66342878341675
# best accuracy = 0.987, parameters = 30208, training time = 95.76313066482544
# best accuracy = 0.9897, parameters = 53000, training time = 96.32445693016052
# best accuracy = 0.9895, parameters = 117688, training time = 107.48461937904358
# best accuracy = 0.9917, parameters = 207848, training time = 173.00293159484863
# best accuracy = 0.9924, parameters = 464584, training time = 244.66418647766113
# best accuracy = 0.9931, parameters = 823208, training time = 308.96614933013916

# %%
plt.rcParams['figure.figsize'] = [12, 12]
fig, ax = plt.subplots()
ax.set_xscale("log")
ax.set_ylim(0.97, 1)

mode_to_color = {
    'naive': 'red',
    'complex': 'green',
    'ga2': 'blue',
}

for mode in modes:
    mid = {}
    for x, y in results[mode]:
        if x not in mid:
            mid[x] = []
        mid[x].append(y)

    mid_pairs = sorted([(x, np.mean(lst)) for x, lst in mid.items()], key=lambda pair: pair[0])
    ax.plot([p[0] for p in mid_pairs], [p[1] for p in mid_pairs], c=mode_to_color[mode], label=mode)

for mode in modes:
    list_of_pairs = results[mode]
    params_counts = [p[0] for p in list_of_pairs]
    accuracies = [p[1] for p in list_of_pairs]

    ax.scatter(params_counts, accuracies, c=mode_to_color[mode], alpha=0.5, marker=r'.')

ax.legend()
plt.xlabel("model parameters count")
plt.ylabel("accuracy")
plt.show()

# %%
results
# Out:
# {'ga2': [(14008, 0.9841),
#   (30544, 0.9872),
#   (53448, 0.9884),
#   (118360, 0.9911),
#   (208744, 0.9917),
#   (465928, 0.9912),
#   (825000, 0.9924),
#   (14008, 0.9821),
#   (30544, 0.9874),
#   (53448, 0.9889),
#   (118360, 0.9911),
#   (208744, 0.9909),
#   (465928, 0.9922),
#   (825000, 0.9933),
#   (14008, 0.9818),
#   (30544, 0.9868),
#   (53448, 0.9885),
#   (118360, 0.9898),
#   (208744, 0.992),
#   (465928, 0.9914),
#   (825000, 0.9923),
#   (14008, 0.9815),
#   (30544, 0.9889),
#   (53448, 0.99),
#   (118360, 0.9909),
#   (208744, 0.9904),
#   (465928, 0.9921),
#   (825000, 0.9936),
#   (14008, 0.9816),
#   (30544, 0.9878),
#   (53448, 0.9898),
#   (118360, 0.9888),
#   (208744, 0.9913),
#   (465928, 0.9917),
#   (825000, 0.9928),
#   (14008, 0.9818),
#   (30544, 0.9886),
#   (53448, 0.9887),
#   (118360, 0.9889),
#   (208744, 0.9912),
#   (465928, 0.9923),
#   (825000, 0.9927),
#   (14008, 0.9822),
#   (30544, 0.9875),
#   (53448, 0.9899),
#   (118360, 0.9893),
#   (208744, 0.9902),
#   (465928, 0.9914),
#   (825000, 0.9932),
#   (14008, 0.982),
#   (30544, 0.9883),
#   (53448, 0.9869),
#   (118360, 0.9904),
#   (208744, 0.9906),
#   (465928, 0.9914),
#   (825000, 0.9932)],
#  'naive': [(13784, 0.9821),
#   (30208, 0.986),
#   (53000, 0.9889),
#   (117688, 0.9905),
#   (207848, 0.9916),
#   (464584, 0.9936),
#   (823208, 0.9936),
#   (13784, 0.9835),
#   (30208, 0.9859),
#   (53000, 0.9897),
#   (117688, 0.992),
#   (207848, 0.9922),
#   (464584, 0.9916),
#   (823208, 0.994),
#   (13784, 0.9812),
#   (30208, 0.9882),
#   (53000, 0.9896),
#   (117688, 0.9893),
#   (207848, 0.9907),
#   (464584, 0.9914),
#   (823208, 0.9936),
#   (13784, 0.9825),
#   (30208, 0.9878),
#   (53000, 0.99),
#   (117688, 0.9905),
#   (207848, 0.9919),
#   (464584, 0.9923),
#   (823208, 0.9927),
#   (13784, 0.9827),
#   (30208, 0.9866),
#   (53000, 0.9896),
#   (117688, 0.9902),
#   (207848, 0.9913),
#   (464584, 0.9926),
#   (823208, 0.9936),
#   (13784, 0.9825),
#   (30208, 0.9886),
#   (53000, 0.9906),
#   (117688, 0.9914),
#   (207848, 0.991),
#   (464584, 0.9929),
#   (823208, 0.9928),
#   (13784, 0.9846),
#   (30208, 0.9881),
#   (53000, 0.9913),
#   (117688, 0.9908),
#   (207848, 0.9918),
#   (464584, 0.9927),
#   (823208, 0.9931),
#   (13784, 0.9868),
#   (30208, 0.987),
#   (53000, 0.9897),
#   (117688, 0.9895),
#   (207848, 0.9917),
#   (464584, 0.9924),
#   (823208, 0.9931)]}
