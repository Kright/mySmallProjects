# %%
import os

from typing import List
from pydantic.dataclasses import dataclass

# %%
with open("ALL.GSC", mode="rb") as f:
    data = f.read()
    
len(data)
# Out:
# 243698958

# %%
def extract_int(data: bytes, offset: int, signed: bool = False):
    return int.from_bytes(data[offset: offset + 4], byteorder="little", signed=signed)

# %%
@dataclass
class Entry:
    hash: bytes
    name: str
    offset: int
    size: int
    flags: int
    
    @staticmethod
    def _to_pretty_name(data) -> str:
        b = data
        while b[-1] == 0:
            b = b[:-1]
        return b.decode('ascii')
    
    @staticmethod
    def parse(data: bytes) -> 'Entry':
        return Entry(
            hash = data[0:4],
            name = Entry._to_pretty_name(data[4: 4 + 64]),
            offset = extract_int(data, 68) ^ 0xFF_FF_FF_FF,
            size = extract_int(data, 72),
            flags = data[76]
        )
    
    @staticmethod
    def parse_all(data: bytes, count: int, offset: int) -> List['Entry']:
        sz = Entry.byte_size()
        return [Entry.parse(data[offset + sz * i: offset + sz * (i + 1)]) for i in range(count)]
    
    @staticmethod
    def byte_size() -> int:
        return 4 + 64 + 4 + 4 + 4 + 1

# %%
entries_offset = 14
entries_count = extract_int(data, 10)
offset_after_entries = entries_offset + Entry.byte_size() * entries_count

entries_count
# Out:
# 5251

# %%
entries = Entry.parse_all(data, entries_count, offset = entries_offset) 

entries
# Out:
# [Entry(hash=b'\xac^\xe1\xcb', name='0\\0TO1.XLT', offset=0, size=256, flags=0),
#  Entry(hash=b'\xc4\xe1\x03\xa4', name='0\\AGEW_1.PAL', offset=256, size=768, flags=0),
#  Entry(hash=b'\xbf\xceI\n', name='0\\AGEW_1BR.GRD', offset=1024, size=8192, flags=0),
#  Entry(hash=b'\xca\xe7\xe1\xfd', name='0\\AGEW_1D.GRD', offset=9216, size=8192, flags=0),
#  Entry(hash=b'\xbf\xceI\x0c', name='0\\AGEW_1DR.GRD', offset=17408, size=40960, flags=0),
#  Entry(hash=b'\xca\xe7\xe1\x0b', name='0\\AGEW_1R.GRD', offset=58368, size=8192, flags=0),
#  Entry(hash=b'\xbf\xce>\x1a', name='0\\AGEW_1RG.GRD', offset=66560, size=8192, flags=0),
#  Entry(hash=b'\xca\xe7\xe1\x10', name='0\\AGEW_1W.GRD', offset=74752, size=8192, flags=0),
#  Entry(hash=b'\xed\xe7\xe1\x0b', name='0\\AGEW_TR.GRD', offset=82944, size=65536, flags=0),
#  Entry(hash=b'\xe2\xce+\x1a', name='0\\AGEW_TR4.GRD', offset=148480, size=65536, flags=0),
#  Entry(hash=b'\xe7\xd4\xeb\xae', name='0\\ALPHAW.GRD', offset=214016, size=65536, flags=0),
#  Entry(hash=b'\xf7\xc9\xd2\x16', name='0\\ALPHAYR.GRD', offset=279552, size=65536, flags=0),
#  Entry(hash=b'\xa5u\t\xb7', name='0\\GRAY.SET', offset=345088, size=256, flags=0),
#  Entry(hash=b'\xdb\xe8\xf1\x9f', name='0\\ORANGE.GRD', offset=345344, size=8192, flags=0),
#  Entry(hash=b'q\xef\x01\xc7', name='0\\WCOST.GRD', offset=353536, size=65536, flags=0),
#  Entry(hash=b'v\xe0\x02\xc1', name='0\\WHITE.GRD', offset=419072, size=8192, flags=0),
#  Entry(hash=b'.\x7fq\x80', name='003.PAL', offset=427264, size=783, flags=0),
#  Entry(hash=b'\x95z^\xc1', name='003CM.GRD', offset=428047, size=8192, flags=0),
#  Entry(hash=b'\x9b\x85w^', name='003W.GRD', offset=436239, size=8192, flags=0),
#  Entry(hash=b'\xa3t\x80^', name='003W.PAL', offset=444431, size=768, flags=0),
#  Entry(hash=b'\xa9z^\xba', name='003WF.GRD', offset=445199, size=8192, flags=0),
#  Entry(hash=b'\xa4t\x80^', name='003X.PAL', offset=453391, size=768, flags=0),
#  Entry(hash=b'\xaaz^\xc6', name='003XR.GRD', offset=454159, size=8192, flags=0),
#  Entry(hash=b'\x9fa\xa5\xd4', name='003XR1.GRD', offset=462351, size=8192, flags=0),
#  Entry(hash=b'\xaaz^\xcb', name='003XW.GRD', offset=470543, size=8192, flags=0),
#  Entry(hash=b'.\x80q\x80', name='004.PAL', offset=478735, size=783, flags=0),
#  Entry(hash=b'\x8b\x86w^', name='004G.GRD', offset=479518, size=8192, flags=0),
#  Entry(hash=b'\xa3u\x80^', name='004W.PAL', offset=487710, size=768, flags=0),
#  Entry(hash=b'\xc4\xe1\x03\xa5', name='1\\AGEW_1.PAL', offset=488478, size=768, flags=0),
#  Entry(hash=b'\xbf\xceI\x0b', name='1\\AGEW_1BR.GRD', offset=489246, size=8192, flags=0),
#  Entry(hash=b'\xca\xe7\xe1\xfe', name='1\\AGEW_1D.GRD', offset=497438, size=8192, flags=0),
#  Entry(hash=b'\xbf\xceI\r', name='1\\AGEW_1DR.GRD', offset=505630, size=40960, flags=0),
#  Entry(hash=b'\xca\xe7\xe1\x0c', name='1\\AGEW_1R.GRD', offset=546590, size=8192, flags=0),
#  Entry(hash=b'\xbf\xce>\x1b', name='1\\AGEW_1RG.GRD', offset=554782, size=8192, flags=0),
#  Entry(hash=b'\xca\xe7\xe1\x11', name='1\\AGEW_1W.GRD', offset=562974, size=8192, flags=0),
#  Entry(hash=b'\xed\xe7\xe1\x0c', name='1\\AGEW_TR.GRD', offset=571166, size=65536, flags=0),
#  Entry(hash=b'\xe2\xce+\x1b', name='1\\AGEW_TR4.GRD', offset=636702, size=65536, flags=0),
#  Entry(hash=b'\xe7\xd4\xeb\xaf', name='1\\ALPHAW.GRD', offset=702238, size=65536, flags=0),
#  Entry(hash=b'\xf7\xc9\xd2\x17', name='1\\ALPHAYR.GRD', offset=767774, size=65536, flags=0),
#  Entry(hash=b'\x8d\x9f\x8a\xc1', name='1\\OLD.PAL', offset=833310, size=768, flags=0),
#  Entry(hash=b'\xdb\xe8\xf1\xa0', name='1\\ORANGE.GRD', offset=834078, size=8192, flags=0),
#  Entry(hash=b'q\xef\x01\xc8', name='1\\WCOST.GRD', offset=842270, size=65536, flags=0),
#  Entry(hash=b'v\xe0\x02\xc2', name='1\\WHITE.GRD', offset=907806, size=8192, flags=0),
#  Entry(hash=b'\x83\x86\xcb\xb3', name='16X16R.RLC', offset=915998, size=24759, flags=0),
#  Entry(hash=b'\x83\x86\xd0\xb3', name='16X16W.RLC', offset=940757, size=31285, flags=0),
#  Entry(hash=b'P.\xa3r', name='1W.PAL', offset=972042, size=768, flags=0),
#  Entry(hash=b'\xac^\xe1\xcd', name='2\\0TO1.XLT', offset=972810, size=256, flags=0),
#  Entry(hash=b'\xc4\xe1\x03\xa6', name='2\\AGEW_1.PAL', offset=973066, size=768, flags=0),
#  Entry(hash=b'\xbf\xceI\x0c', name='2\\AGEW_1BR.GRD', offset=973834, size=8192, flags=0),
#  Entry(hash=b'\xca\xe7\xe1\xff', name='2\\AGEW_1D.GRD', offset=982026, size=8192, flags=0),
#  Entry(hash=b'\xbf\xceI\x0e', name='2\\AGEW_1DR.GRD', offset=990218, size=40960, flags=0),
#  Entry(hash=b'\xca\xe7\xe1\r', name='2\\AGEW_1R.GRD', offset=1031178, size=8192, flags=0),
#  Entry(hash=b'\xbf\xce>\x1c', name='2\\AGEW_1RG.GRD', offset=1039370, size=8192, flags=0),
#  Entry(hash=b'\xca\xe7\xe1\x12', name='2\\AGEW_1W.GRD', offset=1047562, size=8192, flags=0),
#  Entry(hash=b'\xed\xe7\xe1\r', name='2\\AGEW_TR.GRD', offset=1055754, size=65536, flags=0),
#  Entry(hash=b'\xe2\xce+\x1c', name='2\\AGEW_TR4.GRD', offset=1121290, size=65536, flags=0),
#  Entry(hash=b'\xe7\xd4\xeb\xb0', name='2\\ALPHAW.GRD', offset=1186826, size=65536, flags=0),
#  Entry(hash=b'\xf7\xc9\xd2\x18', name='2\\ALPHAYR.GRD', offset=1252362, size=65536, flags=0),
#  Entry(hash=b'\x88r\xeb\xd6', name='2\\DARK.GRD', offset=1317898, size=8192, flags=0),
#  Entry(hash=b'\xdb\xe8\xf1\xa1', name='2\\ORANGE.GRD', offset=1326090, size=8192, flags=0),
#  Entry(hash=b'q\xef\x01\xc9', name='2\\WCOST.GRD', offset=1334282, size=65536, flags=0),
#  Entry(hash=b'P.\xa3s', name='2W.PAL', offset=1399818, size=768, flags=0),
#  Entry(hash=b'T\x95\x8bo', name='ADET.GP', offset=1400586, size=228443, flags=0),
#  Entry(hash=b'T\x89\x91o', name='ADET.MD', offset=1629029, size=6134, flags=0),
#  Entry(hash=b'\x82\x9f\xd9\xcc', name='ADETDEZ.GP', offset=1635163, size=53680, flags=0),
#  Entry(hash=b'.\x91\x88\x91', name='AGE.PAL', offset=1688843, size=768, flags=0),
#  Entry(hash=b'xs\xdd\xd7', name='AGE1DR.GRD', offset=1689611, size=40960, flags=0),
#  Entry(hash=b'\x86\x97\x8eo', name='AGEB.GRD', offset=1730571, size=8192, flags=0),
#  Entry(hash=b'\x88\x97\x8eo', name='AGED.GRD', offset=1738763, size=8192, flags=0),
#  Entry(hash=b'\x97\x8cu\xdd', name='AGEEX.GRD', offset=1746955, size=8192, flags=0),
#  Entry(hash=b'\x99s\xcf\xd8', name='AGERED.GRD', offset=1755147, size=8192, flags=0),
#  Entry(hash=b'\x9b\x97\x8eo', name='AGEW.GRD', offset=1763339, size=8192, flags=0),
#  Entry(hash=b'\xa3\x86\x97o', name='AGEW.PAL', offset=1771531, size=768, flags=0),
#  Entry(hash=b'\xa7s\xc4\xe1', name='AGEW_1.PAL', offset=1772299, size=768, flags=0),
#  Entry(hash=b'\xed\xd9\xbf\xce', name='AGEW_1BR.GRD', offset=1773067, size=8192, flags=0),
#  Entry(hash=b'\x85\xcd\xca\xe7', name='AGEW_1D.GRD', offset=1781259, size=8192, flags=0),
#  Entry(hash=b'\x85\xd5\xb9\xf0', name='AGEW_1D.PAL', offset=1789451, size=768, flags=0),
#  Entry(hash=b'\xed\xdb\xbf\xce', name='AGEW_1DR.GRD', offset=1790219, size=40960, flags=0),
#  Entry(hash=b'\x85\xdb\xca\xe7', name='AGEW_1R.GRD', offset=1831179, size=8192, flags=0),
#  Entry(hash=b'\xe2\xe9\xbf\xce', name='AGEW_1RG.GRD', offset=1839371, size=8192, flags=0),
#  Entry(hash=b'\x85\xe0\xca\xe7', name='AGEW_1W.GRD', offset=1847563, size=8192, flags=0),
#  Entry(hash=b'\x85\xdb\xed\xe7', name='AGEW_TR.GRD', offset=1855755, size=65536, flags=0),
#  Entry(hash=b'\xcf\xe9\xe2\xce', name='AGEW_TR4.GRD', offset=1921291, size=65536, flags=0),
#  Entry(hash=b'\x82\xa0w\xde', name='AI\\AI.DAT', offset=1986827, size=1151, flags=0),
#  Entry(hash=b'\x85\xa0w\xdb', name='AI\\DF.DAT', offset=1987978, size=17, flags=0),
#  Entry(hash=b'\xf1\xe1\xdf\xb0', name='AI_PARAM.DAT', offset=1987995, size=64, flags=0),
#  Entry(hash=b'\x91\x88y\x96', name='AKAAU.GP', offset=1988059, size=184878, flags=0),
#  Entry(hash=b'\x85\x8ey\x96', name='AKAAU.MD', offset=2172937, size=4988, flags=0),
#  Entry(hash=b'\x9b\xd6\xd6\xc4', name='AKAAUDEZ.GP', offset=2177925, size=67121, flags=0),
#  Entry(hash=b'\x92\x88y\x82', name='AKABA.GP', offset=2245046, size=154803, flags=0),
#  Entry(hash=b'\x86\x8ey\x82', name='AKABA.MD', offset=2399849, size=5381, flags=0),
#  Entry(hash=b'\x9c\xd6\xd6\xb0', name='AKABADEZ.GP', offset=2405230, size=53680, flags=0),
#  Entry(hash=b'\x92\x88y\x93', name='AKABR.GP', offset=2458910, size=132474, flags=0),
#  Entry(hash=b'\x86\x8ey\x93', name='AKABR.MD', offset=2591384, size=3755, flags=0),
#  Entry(hash=b'\x9c\xd6\xd6\xc1', name='AKABRDEZ.GP', offset=2595139, size=41815, flags=0),
#  Entry(hash=b'\x94\x88y\x82', name='AKADA.GP', offset=2636954, size=146101, flags=0),
#  Entry(hash=b'\x88\x8ey\x82', name='AKADA.MD', offset=2783055, size=3908, flags=0),
#  Entry(hash=b'\x9e\xd6\xd6\xb0', name='AKADADEZ.GP', offset=2786963, size=33414, flags=0),
#  Entry(hash=b'\x8bo\xa5\xd6', name='AKADEZ.GP', offset=2820377, size=52510, flags=0),
#  Entry(hash=b'\x96\x88y\x93', name='AKAFR.GP', offset=2872887, size=175064, flags=0),
#  Entry(hash=b'\x8a\x8ey\x93', name='AKAFR.MD', offset=3047951, size=5324, flags=0),
#  Entry(hash=b'\xa0\xd6\xd6\xc1', name='AKAFRDEZ.GP', offset=3053275, size=48888, flags=0),
#  Entry(hash=b'\x97\x88y\x86', name='AKAGE.GP', offset=3102163, size=173624, flags=0),
#  Entry(hash=b'\x8b\x8ey\x86', name='AKAGE.MD', offset=3275787, size=4448, flags=0),
#  Entry(hash=b'\xa1\xd6\xd6\xb4', name='AKAGEDEZ.GP', offset=3280235, size=41148, flags=0),
#  Entry(hash=b'\x98\x88y\x90', name='AKAHO.GP', offset=3321383, size=149526, flags=0),
#  Entry(hash=b'\x8c\x8ey\x90', name='AKAHO.MD', offset=3470909, size=3888, flags=0),
#  Entry(hash=b'\xa2\xd6\xd6\xbe', name='AKAHODEZ.GP', offset=3474797, size=30748, flags=0),
#  Entry(hash=b'\xa0\x88y\x8a', name='AKAPI.GP', offset=3505545, size=167114, flags=0),
#  Entry(hash=b'\x94\x8ey\x8a', name='AKAPI.MD', offset=3672659, size=5513, flags=0),
#  Entry(hash=b'\xaa\xd6\xd6\xb8', name='AKAPIDEZ.GP', offset=3678172, size=51563, flags=0),
#  Entry(hash=b'\xa0\x88y\x8d', name='AKAPL.GP', offset=3729735, size=128437, flags=0),
#  Entry(hash=b'\x94\x8ey\x8d', name='AKAPL.MD', offset=3858172, size=4027, flags=0),
#  Entry(hash=b'\xaa\xd6\xd6\xbb', name='AKAPLDEZ.GP', offset=3862199, size=35482, flags=0),
#  Entry(hash=b'\xa0\x88y\x90', name='AKAPO.GP', offset=3897681, size=185873, flags=0),
#  Entry(hash=b'\x94\x8ey\x90', name='AKAPO.MD', offset=4083554, size=4557, flags=0),
#  Entry(hash=b'\xaa\xd6\xd6\xbe', name='AKAPODEZ.GP', offset=4088111, size=53121, flags=0),
#  Entry(hash=b'R\x91\x92o', name='AKAR.GP', offset=4141232, size=175973, flags=0),
#  Entry(hash=b'R\x85\x98o', name='AKAR.MD', offset=4317205, size=5671, flags=0),
#  Entry(hash=b'\xa3\x88y\x82', name='AKASA.GP', offset=4322876, size=174132, flags=0),
#  Entry(hash=b'\x97\x8ey\x82', name='AKASA.MD', offset=4497008, size=5061, flags=0),
#  Entry(hash=b'\xad\xd6\xd6\xb0', name='AKASADEZ.GP', offset=4502069, size=57012, flags=0),
#  Entry(hash=b'\xa3\x88y\x91', name='AKASP.GP', offset=4559081, size=184770, flags=0),
#  Entry(hash=b'\x97\x8ey\x91', name='AKASP.MD', offset=4743851, size=6314, flags=0),
#  Entry(hash=b'\xad\xd6\xd6\xbf', name='AKASPDEZ.GP', offset=4750165, size=80574, flags=0),
#  Entry(hash=b'\xa3\x88y\x97', name='AKASV.GP', offset=4830739, size=143472, flags=0),
#  Entry(hash=b'\x97\x8ey\x97', name='AKASV.MD', offset=4974211, size=4589, flags=0),
#  Entry(hash=b'\xad\xd6\xd6\xc5', name='AKASVDEZ.GP', offset=4978800, size=34103, flags=0),
#  Entry(hash=b'U\x91\x92o', name='AKAU.GP', offset=5012903, size=196615, flags=0),
#  Entry(hash=b'U\x85\x98o', name='AKAU.MD', offset=5209518, size=6583, flags=0),
#  Entry(hash=b'\x83\x9b\xe0\xcc', name='AKAUDEZ.GP', offset=5216101, size=48773, flags=0),
#  Entry(hash=b'\xa6\x88y\x86', name='AKAVE.GP', offset=5264874, size=141555, flags=0),
#  Entry(hash=b'\x9a\x8ey\x86', name='AKAVE.MD', offset=5406429, size=3981, flags=0),
#  Entry(hash=b'\xb0\xd6\xd6\xb4', name='AKAVEDEZ.GP', offset=5410410, size=39678, flags=0),
#  Entry(hash=b'\x8d\x95z\xe6', name='ALGIR.NDS', offset=5450088, size=31832, flags=0),
#  Entry(hash=b"\xe2\xcb\xd9'", name='ALGIR_BLD.BMP', offset=5481920, size=735480, flags=0),
#  Entry(hash=b'\x8f~\xe7\xd4', name='ALPHAW.GRD', offset=6217400, size=65536, flags=0),
#  Entry(hash=b'v\xe6\xf7\xc9', name='ALPHAYR.GRD', offset=6282936, size=65536, flags=0),
#  Entry(hash=b'\x9ar\xe4\xe7', name='ANDMSK.MSK', offset=6348472, size=1024, flags=0),
#  Entry(hash=b'T\x88\x9fo', name='ARDT.MD', offset=6349496, size=2891, flags=0),
#  Entry(hash=b'\x91\x9b\x80\x96', name='ARTAU.GP', offset=6352387, size=181866, flags=0),
#  Entry(hash=b'\x85\xa1\x80\x96', name='ARTAU.MD', offset=6534253, size=5651, flags=0),
#  Entry(hash=b'\x9b\xe9\xdd\xc4', name='ARTAUDEZ.GP', offset=6539904, size=47972, flags=0),
#  Entry(hash=b'\x92\x9b\x80\x82', name='ARTBA.GP', offset=6587876, size=95403, flags=0),
#  Entry(hash=b'\x86\xa1\x80\x82', name='ARTBA.MD', offset=6683279, size=4259, flags=0),
#  Entry(hash=b'\x9c\xe9\xdd\xb0', name='ARTBADEZ.GP', offset=6687538, size=29653, flags=0),
#  Entry(hash=b'\x92\x9b\x80\x93', name='ARTBR.GP', offset=6717191, size=90667, flags=0),
#  Entry(hash=b'\x86\xa1\x80\x93', name='ARTBR.MD', offset=6807858, size=4683, flags=0),
#  Entry(hash=b'\x9c\xe9\xdd\xc1', name='ARTBRDEZ.GP', offset=6812541, size=28265, flags=0),
#  Entry(hash=b'\x94\x9b\x80\x82', name='ARTDA.GP', offset=6840806, size=102388, flags=0),
#  Entry(hash=b'\x88\xa1\x80\x82', name='ARTDA.MD', offset=6943194, size=4737, flags=0),
#  Entry(hash=b'\x9e\xe9\xdd\xb0', name='ARTDADEZ.GP', offset=6947931, size=31430, flags=0),
#  Entry(hash=b'\x96\x9b\x80\x93', name='ARTFR.GP', offset=6979361, size=105142, flags=0),
#  Entry(hash=b'\x8a\xa1\x80\x93', name='ARTFR.MD', offset=7084503, size=4535, flags=0),
#  Entry(hash=b'\xa0\xe9\xdd\xc1', name='ARTFRDEZ.GP', offset=7089038, size=31402, flags=0),
#  Entry(hash=b'\x97\x9b\x80\x86', name='ARTGE.GP', offset=7120440, size=151274, flags=0),
#  Entry(hash=b'\x8b\xa1\x80\x86', name='ARTGE.MD', offset=7271714, size=5570, flags=0),
#  Entry(hash=b'\xa1\xe9\xdd\xb4', name='ARTGEDEZ.GP', offset=7277284, size=36994, flags=0),
#  Entry(hash=b'\x98\x9b\x80\x90', name='ARTHO.GP', offset=7314278, size=97220, flags=0),
#  Entry(hash=b'\x8c\xa1\x80\x90', name='ARTHO.MD', offset=7411498, size=4439, flags=0),
#  Entry(hash=b'\xa2\xe9\xdd\xbe', name='ARTHODEZ.GP', offset=7415937, size=29215, flags=0),
#  Entry(hash=b'\xe8\xdb\xcc6', name='ARTILLERY.BMP', offset=7445152, size=61272, flags=0),
#  Entry(hash=b'\xa0\x9b\x80\x8a', name='ARTPI.GP', offset=7506424, size=126785, flags=0),
#  Entry(hash=b'\x94\xa1\x80\x8a', name='ARTPI.MD', offset=7633209, size=5019, flags=0),
#  Entry(hash=b'\xaa\xe9\xdd\xb8', name='ARTPIDEZ.GP', offset=7638228, size=35244, flags=0),
#  Entry(hash=b'\xa0\x9b\x80\x8d', name='ARTPL.GP', offset=7673472, size=118799, flags=0),
#  Entry(hash=b'\x94\xa1\x80\x8d', name='ARTPL.MD', offset=7792271, size=4385, flags=0),
#  Entry(hash=b'\xaa\xe9\xdd\xbb', name='ARTPLDEZ.GP', offset=7796656, size=32835, flags=0),
#  Entry(hash=b'\xa0\x9b\x80\x90', name='ARTPO.GP', offset=7829491, size=132498, flags=0),
#  Entry(hash=b'\x94\xa1\x80\x90', name='ARTPO.MD', offset=7961989, size=5396, flags=0),
#  Entry(hash=b'\xaa\xe9\xdd\xbe', name='ARTPODEZ.GP', offset=7967385, size=46048, flags=0),
#  Entry(hash=b'\xa2\x9b\x80\x96', name='ARTRU.GP', offset=8013433, size=86664, flags=0),
#  Entry(hash=b'\x96\xa1\x80\x96', name='ARTRU.MD', offset=8100097, size=5212, flags=0),
#  Entry(hash=b'\xac\xe9\xdd\xc4', name='ARTRUDEZ.GP', offset=8105309, size=29287, flags=0),
#  Entry(hash=b'\xa3\x9b\x80\x82', name='ARTSA.GP', offset=8134596, size=159310, flags=0),
#  Entry(hash=b'\x97\xa1\x80\x82', name='ARTSA.MD', offset=8293906, size=5129, flags=0),
#  Entry(hash=b'\xad\xe9\xdd\xb0', name='ARTSADEZ.GP', offset=8299035, size=42486, flags=0),
#  Entry(hash=b'\xa3\x9b\x80\x91', name='ARTSP.GP', offset=8341521, size=145721, flags=0),
#  Entry(hash=b'\x97\xa1\x80\x91', name='ARTSP.MD', offset=8487242, size=5925, flags=0),
#  Entry(hash=b'\xad\xe9\xdd\xbf', name='ARTSPDEZ.GP', offset=8493167, size=46042, flags=0),
#  Entry(hash=b'\xa3\x9b\x80\x97', name='ARTSV.GP', offset=8539209, size=103043, flags=0),
#  Entry(hash=b'\x97\xa1\x80\x97', name='ARTSV.MD', offset=8642252, size=4829, flags=0),
#  Entry(hash=b'\xad\xe9\xdd\xc5', name='ARTSVDEZ.GP', offset=8647081, size=29254, flags=0),
#  Entry(hash=b'T\x98\x9fo', name='ARTT.MD', offset=8676335, size=917, flags=0),
#  Entry(hash=b'U\xa4\x99o', name='ARTU.GP', offset=8677252, size=256508, flags=0),
#  Entry(hash=b'U\x98\x9fo', name='ARTU.MD', offset=8933760, size=7933, flags=0),
#  Entry(hash=b'\x83\xae\xe7\xcc', name='ARTUDEZ.GP', offset=8941693, size=65443, flags=0),
#  Entry(hash=b'\xa6\x9b\x80\x86', name='ARTVE.GP', offset=9007136, size=119351, flags=0),
#  Entry(hash=b'\x9a\xa1\x80\x86', name='ARTVE.MD', offset=9126487, size=5455, flags=0),
#  Entry(hash=b'\xb0\xe9\xdd\xb4', name='ARTVEDEZ.GP', offset=9131942, size=36499, flags=0),
#  Entry(hash=b'\xacz\x85\xc7', name='ATL_B1.MD', offset=9168441, size=2856, flags=0),
#  Entry(hash=b'\x82\xe7\xe2\xe1', name='AUSTRIA.NDS', offset=9171297, size=72719, flags=0),
#  Entry(hash=b'\xe1(8\x18', name='AUSTRIA_BLD.BMP', offset=9244016, size=735480, flags=0),
#  Entry(hash=b'.1\x85\x8f', name='BA1.MD', offset=9979496, size=709, flags=0),
#  Entry(hash=b'B\x81\x88p', name='BA1B.GP', offset=9980205, size=157857, flags=0),
#  Entry(hash=b'C\x81\x88p', name='BA1C.GP', offset=10138062, size=32429, flags=0),
#  Entry(hash=b'G\x81\x88p', name='BA1G.GP', offset=10170491, size=159950, flags=0),
#  Entry(hash=b'H\x81\x88p', name='BA1H.GP', offset=10330441, size=205236, flags=0),
#  Entry(hash=b'\x96}\x93p', name='BA1S.RLC', offset=10535677, size=7362, flags=0),
#  Entry(hash=b'.E\x85\x8f', name='BAE.MD', offset=10543039, size=555, flags=0),
#  Entry(hash=b'B\x95\x88p', name='BAEB.GP', offset=10543594, size=193498, flags=0),
#  Entry(hash=b'C\x95\x88p', name='BAEC.GP', offset=10737092, size=38114, flags=0),
#  Entry(hash=b'G\x95\x88p', name='BAEG.GP', offset=10775206, size=194289, flags=0),
#  Entry(hash=b'H\x95\x88p', name='BAEH.GP', offset=10969495, size=267430, flags=0),
#  Entry(hash=b'.R\x85\x8f', name='BAR.MD', offset=11236925, size=543, flags=0),
#  Entry(hash=b'B\xa2\x88p', name='BARB.GP', offset=11237468, size=187011, flags=0),
#  Entry(hash=b'C\xa2\x88p', name='BARC.GP', offset=11424479, size=37289, flags=0),
#  Entry(hash=b'G\xa2\x88p', name='BARG.GP', offset=11461768, size=186209, flags=0),
#  Entry(hash=b'H\xa2\x88p', name='BARH.GP', offset=11647977, size=251131, flags=0),
#  Entry(hash=b'.S\x85\x8f', name='BAS.MD', offset=11899108, size=1090, flags=0),
#  Entry(hash=b'.T\x91\x89', name='BAT.GP', offset=11900198, size=75081, flags=0),
#  Entry(hash=b'.T\x85\x8f', name='BAT.MD', offset=11975279, size=3624, flags=0),
#  Entry(hash=b'\x8b\x82\x9b\xd7', name='BATDEZ.GP', offset=11978903, size=25035, flags=0),
#  Entry(hash=b'o\xea\xce\xe2', name='BAVARIA.NDS', offset=12003938, size=62442, flags=0),
#  Entry(hash=b'\xce+$\x19', name='BAVARIA_BLD.BMP', offset=12066380, size=735480, flags=0),
#  Entry(hash=b'\xaf\xd6\xd2\xa2', name='BGAU2DEZ.GP', offset=12801860, size=26082, flags=0),
#  Entry(hash=b'\xa5\x88u\x9c', name='BGAUZ.GP', offset=12827942, size=36566, flags=0),
#  Entry(hash=b'\x99\x8eu\x9c', name='BGAUZ.MD', offset=12864508, size=4025, flags=0),
#  Entry(hash=b'\x9coy\xec', name='BGAUZ2.GP', offset=12868533, size=37227, flags=0),
#  Entry(hash=b'\xa2oy\xe0', name='BGAUZ2.MD', offset=12905760, size=3442, flags=0),
#  Entry(hash=b'\xaf\xd6\xd2\xca', name='BGAUZDEZ.GP', offset=12909202, size=27135, flags=0),
#  Entry(hash=b'\x8b\x80\xa1\xd7', name='BORDER.GP', offset=12936337, size=211583, flags=0),
#  Entry(hash=b'.T\x96\x8f', name='BRT.MD', offset=13147920, size=675, flags=0),
#  Entry(hash=b'B\xa4\x99p', name='BRTB.GP', offset=13148595, size=184056, flags=0),
#  Entry(hash=b'H\xa4\x99p', name='BRTH.GP', offset=13332651, size=235286, flags=0),
#  Entry(hash=b'.I\xa5\x89', name='BUI.GP', offset=13567937, size=31499, flags=0),
#  Entry(hash=b'.I\x99\x8f', name='BUI.MD', offset=13599436, size=506, flags=0),
#  Entry(hash=b'.L\x91\x8a', name='CAL.GP', offset=13599942, size=131056, flags=0),
#  Entry(hash=b'.L\x85\x90', name='CAL.MD', offset=13730998, size=4552, flags=0),
#  Entry(hash=b'\x8bz\x9b\xd8', name='CALDEZ.GP', offset=13735550, size=33728, flags=0),
#  Entry(hash=b'.U\x91\x8a', name='CAU.GP', offset=13769278, size=209568, flags=0),
#  Entry(hash=b'.U\x85\x90', name='CAU.MD', offset=13978846, size=6646, flags=0),
#  Entry(hash=b'\x8b\x83\x9b\xd8', name='CAUDEZ.GP', offset=13985492, size=61426, flags=0),
#  Entry(hash=b'.B\x89\x90', name='CEB.MD', offset=14046918, size=4743, flags=0),
#  Entry(hash=b'A\x92\x8cq', name='CEBA.GP', offset=14051661, size=134548, flags=0),
#  Entry(hash=b'A\x86\x92q', name='CEBA.MD', offset=14186209, size=4283, flags=0),
#  Entry(hash=b'o\x9c\xda\xce', name='CEBADEZ.GP', offset=14190492, size=47576, flags=0),
#  Entry(hash=b'\x92\x89s\x95', name='CEBBR.GP', offset=14238068, size=154619, flags=0),
#  Entry(hash=b'\x9c\xd7\xd0\xc3', name='CEBBRDEZ.GP', offset=14392687, size=40347, flags=0),
#  Entry(hash=b'A\x94\x8cq', name='CEDA.GP', offset=14433034, size=139471, flags=0),
#  Entry(hash=b'A\x88\x92q', name='CEDA.MD', offset=14572505, size=4495, flags=0),
#  Entry(hash=b'o\x9e\xda\xce', name='CEDADEZ.GP', offset=14577000, size=34327, flags=0),
#  Entry(hash=b'.F\x95\x8a', name='CEF.GP', offset=14611327, size=168534, flags=0),
#  Entry(hash=b'2\x8a\x92q', name='CEF2.MD', offset=14779861, size=5312, flags=0),
#  Entry(hash=b'\x8bt\x9f\xd8', name='CEFDEZ.GP', offset=14785173, size=53530, flags=0),
#  Entry(hash=b'.H\x95\x8a', name='CEH.GP', offset=14838703, size=153077, flags=0),
#  Entry(hash=b'.H\x89\x90', name='CEH.MD', offset=14991780, size=3889, flags=0),
#  Entry(hash=b'\x8bv\x9f\xd8', name='CEHDEZ.GP', offset=14995669, size=42816, flags=0),
#  Entry(hash=b'.I\x95\x8a', name='CEI.GP', offset=15038485, size=235002, flags=0),
#  Entry(hash=b'.I\x89\x90', name='CEI.MD', offset=15273487, size=5425, flags=0),
#  Entry(hash=b'\x8bw\x9f\xd8', name='CEIDEZ.GP', offset=15278912, size=64098, flags=0),
#  Entry(hash=b'.P\x95\x8a', name='CEP.GP', offset=15343010, size=205090, flags=0),
#  Entry(hash=b'.P\x89\x90', name='CEP.MD', offset=15548100, size=5669, flags=0),
#  Entry(hash=b'\x8b~\x9f\xd8', name='CEPDEZ.GP', offset=15553769, size=60835, flags=0),
#  Entry(hash=b'\x8b\x80\x9f\xd8', name='CERDEZ.GP', offset=15614604, size=77557, flags=0),
#  Entry(hash=b'U\xa2\x8cq', name='CERU.GP', offset=15692161, size=154874, flags=0),
#  Entry(hash=b'U\x96\x92q', name='CERU.MD', offset=15847035, size=5002, flags=0),
#  Entry(hash=b'\x83\xac\xda\xce', name='CERUDEZ.GP', offset=15852037, size=33397, flags=0),
#  Entry(hash=b'.S\x95\x8a', name='CES.GP', offset=15885434, size=165105, flags=0),
#  Entry(hash=b'.S\x89\x90', name='CES.MD', offset=16050539, size=5147, flags=0),
#  Entry(hash=b'\x8b\x81\x9f\xd8', name='CESDEZ.GP', offset=16055686, size=52796, flags=0),
#  Entry(hash=b'.T\x95\x8a', name='CET.GP', offset=16108482, size=78636, flags=0),
#  Entry(hash=b'.T\x89\x90', name='CET.MD', offset=16187118, size=4319, flags=0),
#  Entry(hash=b'\x8b\x82\x9f\xd8', name='CETDEZ.GP', offset=16191437, size=37837, flags=0),
#  Entry(hash=b'.V\x95\x8a', name='CEV.GP', offset=16229274, size=288611, flags=0),
#  Entry(hash=b'.V\x89\x90', name='CEV.MD', offset=16517885, size=6613, flags=0),
#  Entry(hash=b'\x8b\x84\x9f\xd8', name='CEVDEZ.GP', offset=16524498, size=74949, flags=0),
#  Entry(hash=b'\x9c3|\x96', name='CLANS\\-RUS-\\-RUS-.BMP', offset=16599447, size=2278, flags=0),
#  Entry(hash=b'\x80I`\xac', name='CLANS\\12BWR\\12BWR.BMP', offset=16601725, size=2278, flags=0),
#  Entry(hash=b'\xe4TcG', name='CLANS\\1776\\1776.BMP', offset=16604003, size=2918, flags=0),
#  Entry(hash=b'1\xe62u', name='CLANS\\1KG\\1KG.BMP', offset=16606921, size=2280, flags=0),
#  Entry(hash=b'\x1d\x063m', name='CLANS\\AAC\\AAC.BMP', offset=16609201, size=2118, flags=0),
#  Entry(hash=b'\x00\x82\xa1t', name='CLANS\\ACXS\\ACXS.BMP', offset=16611319, size=2278, flags=0),
#  Entry(hash=b'\xc2\x1875', name='CLANS\\AF\\AF.BMP', offset=16613597, size=2118, flags=0),
#  Entry(hash=b"'\x063\x8b", name='CLANS\\AFR\\AFR.BMP', offset=16615715, size=2518, flags=0),
#  Entry(hash=b'\xc5\x1b75', name='CLANS\\AI\\AI.BMP', offset=16618233, size=2918, flags=0),
#  Entry(hash=b'7\x063i', name='CLANS\\ANA\\ANA.BMP', offset=16621151, size=3078, flags=0),
#  Entry(hash=b'9\x063\x8d', name='CLANS\\AOS\\AOS.BMP', offset=16624229, size=2278, flags=0),
#  Entry(hash=b'\x1d\x083m', name='CLANS\\BAC\\BAC.BMP', offset=16626507, size=2118, flags=0),
#  Entry(hash=b'9\x083\x8d', name='CLANS\\BOS\\BOS.BMP', offset=16628625, size=2280, flags=0),
#  Entry(hash=b'\xd3*85', name='CLANS\\BW\\BW.BMP', offset=16630905, size=2438, flags=0),
#  Entry(hash=b'\x1f\n3w', name='CLANS\\CBH\\CBH.BMP', offset=16633343, size=3078, flags=0),
#  Entry(hash=b'\x01w\x8em', name='CLANS\\CBRF\\CBRF.BMP', offset=16636421, size=1718, flags=0),
#  Entry(hash=b'#\n3\x93', name='CLANS\\CDV\\CDV.BMP', offset=16638139, size=1960, flags=0),
#  Entry(hash=b')\n3y', name='CLANS\\CGI\\CGI.BMP', offset=16640099, size=2280, flags=0),
#  Entry(hash=b'\x07\x83\x8eg', name='CLANS\\CHFR\\CHFR.BMP', offset=16642379, size=2278, flags=0),
#  Entry(hash=b'3\n3q', name='CLANS\\CLE\\CLE.BMP', offset=16644657, size=2918, flags=0),
#  Entry(hash=b'9\n3m', name='CLANS\\COC\\COC.BMP', offset=16647575, size=3814, flags=0),
#  Entry(hash=b'A\n3s', name='CLANS\\CSF\\CSF.BMP', offset=16651389, size=2118, flags=0),
#  Entry(hash=b'\xd0(95', name='CLANS\\CT\\CT.BMP', offset=16653507, size=4118, flags=0),
#  Entry(hash=b'\xd3+95', name='CLANS\\CW\\CW.BMP', offset=16657625, size=1718, flags=0),
#  Entry(hash=b'\x1f\x0c3\x9b', name='CLANS\\DBZ\\DBZ.BMP', offset=16659343, size=2198, flags=0),
#  Entry(hash=b'\xc3\x1c:5', name='CLANS\\DG\\DG.BMP', offset=16661541, size=2806, flags=0),
#  Entry(hash=b'\xc4\x1d:5', name='CLANS\\DH\\DH.BMP', offset=16664347, size=2118, flags=0),
#  Entry(hash=b'\x91\\q\xbf', name='CLANS\\DHERO\\DHERO.BMP', offset=16666465, size=2118, flags=0),
#  Entry(hash=b"\xce':5", name='CLANS\\DR\\DR.BMP', offset=16668583, size=2118, flags=0),
#  Entry(hash=b'C\x0c3\x8b', name='CLANS\\DTR\\DTR.BMP', offset=16670701, size=2278, flags=0),
#  Entry(hash=b'iWI\xba', name='CLANS\\E-BEL\\E-BEL.BMP', offset=16672979, size=2278, flags=0),
#  Entry(hash=b'\x8bsk\xd6', name='CLANS\\FAUST\\FAUST.BMP', offset=16675257, size=4374, flags=0),
#  Entry(hash=b'\xc4\x1f<5', name='CLANS\\FH\\FH.BMP', offset=16679631, size=2278, flags=0),
#  Entry(hash=b'\xd3.<5', name='CLANS\\FW\\FW.BMP', offset=16681909, size=2118, flags=0),
#  Entry(hash=b'\xbd\x19=5', name='CLANS\\GA\\GA.BMP', offset=16684027, size=2278, flags=0),
#  Entry(hash=b'\x84cd\xc6', name='CLANS\\GAELS\\GAELS.BMP', offset=16686305, size=1638, flags=0),
#  Entry(hash=b'\x1f\x123m', name='CLANS\\GBC\\GBC.BMP', offset=16687943, size=2278, flags=0),
#  Entry(hash=b'\x08\x89\x98l', name='CLANS\\GENT\\GENT.BMP', offset=16690221, size=2278, flags=0),
#  Entry(hash=b'\x11x\x7fm', name='CLANS\\GNFC\\GNFC.BMP', offset=16692499, size=2598, flags=0),
#  Entry(hash=b'9\x123\x8f', name='CLANS\\GOT\\GOT.BMP', offset=16695097, size=2134, flags=0),
#  Entry(hash=b'\xce*=5', name='CLANS\\GR\\GR.BMP', offset=16697231, size=1878, flags=0),
#  Entry(hash=b'?\x123k', name='CLANS\\GRB\\GRB.BMP', offset=16699109, size=2758, flags=0),
#  Entry(hash=b'_\xbc\xc4\xbc', name='CLANS\\GREBEL\\GREBEL.BMP', offset=16701867, size=2518, flags=0),
#  Entry(hash=b'\x96bv\xc5', name='CLANS\\GREMR\\GREMR.BMP', offset=16704385, size=2198, flags=0),
#  Entry(hash=b'?\x123\x95', name='CLANS\\GRW\\GRW.BMP', offset=16706583, size=2278, flags=0),
#  Entry(hash=b'\xd3/=5', name='CLANS\\GW\\GW.BMP', offset=16708861, size=2198, flags=0),
#  Entry(hash=b'\xff\x133\x8d', name='CLANS\\H2S\\H2S.BMP', offset=16711059, size=1798, flags=0),
#  Entry(hash=b'\xe0b\xb1\x7f', name='CLANS\\H2S\\H2S_A.BMP', offset=16712857, size=2358, flags=0),
#  Entry(hash=b'\xe0c\xb1\x7f', name='CLANS\\H2S\\H2S_B.BMP', offset=16715215, size=2358, flags=0),
#  Entry(hash=b'\xe0d\xb1\x7f', name='CLANS\\H2S\\H2S_C.BMP', offset=16717573, size=2358, flags=0),
#  Entry(hash=b'\xc7$>5', name='CLANS\\HK\\HK.BMP', offset=16719931, size=2118, flags=0),
#  Entry(hash=b'E\x143\x83', name='CLANS\\HUN\\HUN.BMP', offset=16722049, size=2438, flags=0),
#  Entry(hash=b'!\x163m', name='CLANS\\ICC\\ICC.BMP', offset=16724487, size=2118, flags=0),
#  Entry(hash=b'\x0bx\x8ct', name='CLANS\\IFUA\\IFUA.BMP', offset=16726605, size=2118, flags=0),
#  Entry(hash=b'C\x163i', name='CLANS\\ITA\\ITA.BMP', offset=16728723, size=2278, flags=0),
#  Entry(hash=b'\x0b\x81\x83b', name='CLANS\\JEDI\\JEDI.BMP', offset=16731001, size=3078, flags=0),
#  Entry(hash=b'-\x183i', name='CLANS\\JIA\\JIA.BMP', offset=16734079, size=2598, flags=0),
#  Entry(hash=b'\xbd\x1dA5', name='CLANS\\KA\\KA.BMP', offset=16736677, size=2278, flags=0),
#  Entry(hash=b'\x0b\x8c\x93g', name='CLANS\\KDJS\\KDJS.BMP', offset=16738955, size=2118, flags=0),
#  Entry(hash=b'\x10\x8f\x91g', name='CLANS\\KIEV\\KIEV.BMP', offset=16741073, size=2038, flags=0),
#  Entry(hash=b'9\x1a3m', name='CLANS\\KOC\\KOC.BMP', offset=16743111, size=2518, flags=0),
#  Entry(hash=b'A\x1a3s', name='CLANS\\KSF\\KSF.BMP', offset=16745629, size=2198, flags=0),
#  Entry(hash=b'!\x1c3i', name='CLANS\\LCA\\LCA.BMP', offset=16747827, size=2038, flags=0),
#  Entry(hash=b'!\x1c3k', name='CLANS\\LCB\\LCB.BMP', offset=16749865, size=2678, flags=0),
#  Entry(hash=b'%\x1c3u', name='CLANS\\LEG\\LEG.BMP', offset=16752543, size=2598, flags=0),
#  Entry(hash=b')\x1c3\x8f', name='CLANS\\LGT\\LGT.BMP', offset=16755141, size=2278, flags=0),
#  Entry(hash=b'\x95vu\xd9', name='CLANS\\LINUX\\LINUX.BMP', offset=16757419, size=2518, flags=0),
#  Entry(hash=b'\x1ak\xb1a', name='CLANS\\LOD\\LOD_A.BMP', offset=16759937, size=2118, flags=0),
#  Entry(hash=b'\x1al\xb1a', name='CLANS\\LOD\\LOD_B.BMP', offset=16762055, size=2118, flags=0),
#  Entry(hash=b'\x1am\xb1a', name='CLANS\\LOD\\LOD_C.BMP', offset=16764173, size=2118, flags=0),
#  Entry(hash=b'Y\x1c3\x7f', name='CLANS\\L_L\\L_L.BMP', offset=16766291, size=2218, flags=0),
#  Entry(hash=b'S]3\xc0', name='CLANS\\M.I.C\\M.I.C.BMP', offset=16768509, size=2278, flags=0),
#  Entry(hash=b'\xfd\x1d3m', name='CLANS\\M1C\\M1C.BMP', offset=16770787, size=3798, flags=0),
#  Entry(hash=b'\xc0"C5', name='CLANS\\MD\\MD.BMP', offset=16774585, size=2278, flags=0),
#  Entry(hash=b'#\x1e3\x8b', name='CLANS\\MDR\\MDR.BMP', offset=16776863, size=2280, flags=0),
#  Entry(hash=b'mfM\xc9', name='CLANS\\MDR2C\\MDR2C.BMP', offset=16779143, size=2278, flags=0),
#  Entry(hash=b'7\x1e3\x8d', name='CLANS\\MNS\\MNS.BMP', offset=16781421, size=3078, flags=0),
#  Entry(hash=b'9\x1e3w', name='CLANS\\MOH\\MOH.BMP', offset=16784499, size=2118, flags=0),
#  Entry(hash=b'\x18|\x8b|', name='CLANS\\MOTA\\MOTA.BMP', offset=16786617, size=1858, flags=0),
#  Entry(hash=b'\x18\x82\x91|', name='CLANS\\MOTG\\MOTG.BMP', offset=16788475, size=2118, flags=0),
#  Entry(hash=b'\x18\x81\x93\x7f', name='CLANS\\MOWF\\MOWF.BMP', offset=16790593, size=2278, flags=0),
#  Entry(hash=b'A\x1e3\x83', name='CLANS\\MSN\\MSN.BMP', offset=16792871, size=2278, flags=0),
#  Entry(hash=b'A\x1e3\x91', name='CLANS\\MSU\\MSU.BMP', offset=16795149, size=1878, flags=0),
#  Entry(hash=b'\xd02C5', name='CLANS\\MT\\MT.BMP', offset=16797027, size=2142, flags=0),
#  Entry(hash=b'\xa4|\x84\xdf', name='CLANS\\MYSTX\\MYSTX.BMP', offset=16799169, size=3078, flags=0),
#  Entry(hash=b'! 3m', name='CLANS\\NCC\\NCC.BMP', offset=16802247, size=2438, flags=0),
#  Entry(hash=b'\xc2%D5', name='CLANS\\NF\\NF.BMP', offset=16804685, size=2278, flags=0),
#  Entry(hash=b'9 3i', name='CLANS\\NOA\\NOA.BMP', offset=16806963, size=3078, flags=0),
#  Entry(hash=b'A 3s', name='CLANS\\NSF\\NSF.BMP', offset=16810041, size=2598, flags=0),
#  Entry(hash=b'\xbf#E5', name='CLANS\\OC\\OC.BMP', offset=16812639, size=2278, flags=0),
#  Entry(hash=b'\x8eYn\xbc', name='CLANS\\ODESA\\ODESA.BMP', offset=16814917, size=1678, flags=0),
#  Entry(hash=b'\x13\x81}d', name='CLANS\\PGDC\\PGDC.BMP', offset=16816595, size=2278, flags=0),
#  Entry(hash=b'9$3m', name='CLANS\\POC\\POC.BMP', offset=16818873, size=2118, flags=0),
#  Entry(hash=b'9$3\x8f', name='CLANS\\POT\\POT.BMP', offset=16820991, size=2278, flags=0),
#  Entry(hash=b'\x1cs\xb1o', name='CLANS\\PPK\\PPK_A.BMP', offset=16823269, size=2278, flags=0),
#  Entry(hash=b'\x1ct\xb1o', name='CLANS\\PPK\\PPK_B.BMP', offset=16825547, size=2278, flags=0),
#  Entry(hash=b'C$3q', name='CLANS\\PTE\\PTE.BMP', offset=16827825, size=2998, flags=0),
#  Entry(hash=b'E$3\x8b', name='CLANS\\PUR\\PUR.BMP', offset=16830823, size=2118, flags=0),
#  Entry(hash=b'G&3o', name='CLANS\\QVD\\QVD.BMP', offset=16832941, size=2118, flags=0),
#  Entry(hash=b'\x7f`_\xc3', name='CLANS\\REECE\\REECE.BMP', offset=16835059, size=2518, flags=0),
#  Entry(hash=b'-(3\x87', name='CLANS\\RIP\\RIP.BMP', offset=16837577, size=2278, flags=0),
#  Entry(hash=b'\xcc3H5', name='CLANS\\RP\\RP.BMP', offset=16839855, size=2118, flags=0),
#  Entry(hash=b'#\x8f\x88q', name='CLANS\\RUCO\\RUCO.BMP', offset=16841973, size=3318, flags=0),
#  Entry(hash=b'#\x81\x82y', name='CLANS\\RUKA\\RUKA.BMP', offset=16845291, size=2278, flags=0),
#  Entry(hash=b"\xbf'I5", name='CLANS\\SC\\SC.BMP', offset=16847569, size=2278, flags=0),
#  Entry(hash=b'!*3m', name='CLANS\\SCC\\SCC.BMP', offset=16849847, size=2518, flags=0),
#  Entry(hash=b'#*3\x8f', name='CLANS\\SDT\\SDT.BMP', offset=16852365, size=2278, flags=0),
#  Entry(hash=b'\x87cg\xc6', name='CLANS\\SMACK\\SMACK.BMP', offset=16854643, size=2918, flags=0),
#  Entry(hash=b'\x1d\x84|j', name='CLANS\\SNCC\\SNCC.BMP', offset=16857561, size=2278, flags=0),
#  Entry(hash=b'9*3\x8b', name='CLANS\\SOR\\SOR.BMP', offset=16859839, size=2038, flags=0),
#  Entry(hash=b'\xcc4I5', name='CLANS\\SP\\SP.BMP', offset=16861877, size=2118, flags=0),
#  Entry(hash=b';*3m', name='CLANS\\SPC\\SPC.BMP', offset=16863995, size=2278, flags=0),
#  Entry(hash=b'I*3\x8b', name='CLANS\\SWR\\SWR.BMP', offset=16866273, size=1958, flags=0),
#  Entry(hash=b'K*3o', name='CLANS\\SXD\\SXD.BMP', offset=16868231, size=1878, flags=0),
#  Entry(hash=b'!,3\x8f', name='CLANS\\TCT\\TCT.BMP', offset=16870109, size=2518, flags=0),
#  Entry(hash=b'),3m', name='CLANS\\TGC\\TGC.BMP', offset=16872627, size=2218, flags=0),
#  Entry(hash=b'),3\x95', name='CLANS\\TGW\\TGW.BMP', offset=16874845, size=2280, flags=0),
#  Entry(hash=b'\x97yw\xdc', name='CLANS\\TLOTR\\TLOTR.BMP', offset=16877125, size=4118, flags=0),
#  Entry(hash=b'5,3k', name='CLANS\\TMB\\TMB.BMP', offset=16881243, size=2522, flags=0),
#  Entry(hash=b'\xcc5J5', name='CLANS\\TP\\TP.BMP', offset=16883765, size=2278, flags=0),
#  Entry(hash=b'?,3m', name='CLANS\\TRC\\TRC.BMP', offset=16886043, size=2278, flags=0),
#  Entry(hash=b'\xd5>J5', name='CLANS\\TY\\TY.BMP', offset=16888321, size=2918, flags=0),
#  Entry(hash=b'Y,3m', name='CLANS\\T_C\\T_C.BMP', offset=16891239, size=2358, flags=0),
#  Entry(hash=b'Sg3\xca', name='CLANS\\U.K.C\\U.K.C.BMP', offset=16893597, size=3078, flags=0),
#  Entry(hash=b'%.3}', name='CLANS\\UEK\\UEK.BMP', offset=16896675, size=2118, flags=0),
#  Entry(hash=b'\xc71K5', name='CLANS\\UK\\UK.BMP', offset=16898793, size=2278, flags=0),
#  Entry(hash=b'?.3\x87', name='CLANS\\URP\\URP.BMP', offset=16901071, size=2278, flags=0),
#  Entry(hash=b'$\x89}m', name='CLANS\\USAF\\USAF.BMP', offset=16903349, size=2518, flags=0),
#  Entry(hash=b'\x90mp\xd0', name='CLANS\\USAFS\\USAFS.BMP', offset=16905867, size=2518, flags=0),
#  Entry(hash=b'903m', name='CLANS\\VOC\\VOC.BMP', offset=16908385, size=2438, flags=0),
#  Entry(hash=b'\xcc7L5', name='CLANS\\VP\\VP.BMP', offset=16910823, size=4118, flags=0),
#  Entry(hash=b'!23\x87', name='CLANS\\WCP\\WCP.BMP', offset=16914941, size=2278, flags=0),
#  Entry(hash=b'\x1b\x97\x92k', name='CLANS\\ZEMO\\ZEMO.BMP', offset=16917219, size=4118, flags=0),
#  Entry(hash=b'\x85\x80e\xe3', name='CLANS\\ZENIT\\ZENIT.BMP', offset=16921337, size=2278, flags=0),
#  Entry(hash=b'{\xf5\xf5\xdc', name='COMMENT.TXT', offset=16923615, size=40088, flags=0),
#  Entry(hash=b'~\xf9\xe7\xdb', name='COMPLEX.LST', offset=16963703, size=1337, flags=0),
#  Entry(hash=b'~\xf7\xe7\xe1', name='COMPLEX.RSR', offset=16965040, size=1146, flags=0),
#  Entry(hash=b'\xa6\x9a}\xeb', name='CONST.LST', offset=16966186, size=3437, flags=0),
#  Entry(hash=b'.L\xa0\x8a', name='CPL.GP', offset=16969623, size=168026, flags=0),
#  Entry(hash=b'.L\x94\x90', name='CPL.MD', offset=17137649, size=4292, flags=0),
#  Entry(hash=b'\x8bz\xaa\xd8', name='CPLDEZ.GP', offset=17141941, size=35086, flags=0),
#  Entry(hash=b'.O\xa0\x8a', name='CPO.GP', offset=17177027, size=145286, flags=0),
#  Entry(hash=b'.O\x94\x90', name='CPO.MD', offset=17322313, size=4291, flags=0),
#  Entry(hash=b'\x8b}\xaa\xd8', name='CPODEZ.GP', offset=17326604, size=50782, flags=0),
#  Entry(hash=b'.P\xa2\x8a', name='CRP.GP', offset=17377386, size=179585, flags=0),
#  Entry(hash=b'.P\x96\x90', name='CRP.MD', offset=17556971, size=5273, flags=0),
#  Entry(hash=b'\x8b~\xac\xd8', name='CRPDEZ.GP', offset=17562244, size=43353, flags=0),
#  Entry(hash=b'.W\xa3\x8a', name='CSW.GP', offset=17605597, size=213940, flags=0),
#  Entry(hash=b'.W\x97\x90', name='CSW.MD', offset=17819537, size=6030, flags=0),
#  Entry(hash=b'\x8b\x85\xad\xd8', name='CSWDEZ.GP', offset=17825567, size=70318, flags=0),
#  Entry(hash=b'.R\xa5\x8a', name='CUR.GP', offset=17895885, size=169055, flags=0),
#  Entry(hash=b'.R\x99\x90', name='CUR.MD', offset=18064940, size=7668, flags=0),
#  Entry(hash=b'\x8b\x80\xaf\xd8', name='CURDEZ.GP', offset=18072608, size=42915, flags=0),
#  Entry(hash=b'\xd3\xf8\xd5\xc2', name='CURSOR_00.GP', offset=18115523, size=11145, flags=0),
#  Entry(hash=b'\xd3\xf8\xd5\xc3', name='CURSOR_01.GP', offset=18126668, size=12098, flags=0),
#  Entry(hash=b'\xd3\xf8\xd5\xc4', name='CURSOR_02.GP', offset=18138766, size=12035, flags=0),
#  Entry(hash=b'\xef\xfd\xf9\xc0', name='CURSOR_Y.RLC', offset=18150801, size=2603, flags=0),
#  Entry(hash=b'\xb1\x80\xe6\xdc', name='CUR_MN.RLC', offset=18153404, size=2603, flags=0),
#  Entry(hash=b'.L\x91\x8b', name='DAL.GP', offset=18156007, size=69590, flags=0),
#  Entry(hash=b'.L\x85\x91', name='DAL.MD', offset=18225597, size=2714, flags=0),
#  Entry(hash=b'\x8bz\x9b\xd9', name='DALDEZ.GP', offset=18228311, size=19319, flags=0),
#  Entry(hash=b'y\xdb\xda\xcc', name='DARKAGE.GRD', offset=18247630, size=40960, flags=0),
#  Entry(hash=b'\x9d\x99o\xca', name='DARKB.GRD', offset=18288590, size=8192, flags=0),
#  Entry(hash=b'y\xdd\xe2\xd1', name='DARKFOG.GRD', offset=18296782, size=40960, flags=0),
#  Entry(hash=b'\x9d\x99o\xda', name='DARKR.GRD', offset=18337742, size=8192, flags=0),
#  Entry(hash=b'\x9d\x99o\xdf', name='DARKW.GRD', offset=18345934, size=8192, flags=0),
#  Entry(hash=b'\x8c\xa2o\xe7', name='DARKW.PAL', offset=18354126, size=768, flags=0),
#  Entry(hash=b'o\xd5\xbe\xe2', name='DATA\\01.BMP', offset=18354894, size=196662, flags=0),
#  Entry(hash=b'o\xd6\xbe\xe2', name='DATA\\02.BMP', offset=18551556, size=196662, flags=0),
#  Entry(hash=b'o\xd7\xbe\xe2', name='DATA\\03.BMP', offset=18748218, size=196662, flags=0),
#  Entry(hash=b'\xc5\xea\xb2%', name='DATA\\CRC1.DAT', offset=18944880, size=0, flags=0),
#  Entry(hash=b'-\x1f\n{', name='DATA\\KEYBOARD.DAT', offset=18944880, size=1319, flags=0),
#  Entry(hash=b'\xb3M62', name='DATA\\ORDERS.LST', offset=18946199, size=11411, flags=0),
#  Entry(hash=b'dsc\xcf', name='DATA\\SCED_DEFAULT.BMP', offset=18957610, size=57144, flags=0),
#  Entry(hash=b'\r:\x04\x8a', name='DATA\\SOFTAREA.DAT', offset=19014754, size=65535, flags=0),
#  Entry(hash=b'\xb0-*7', name='DATA\\START1.DAT', offset=19080289, size=8659, flags=0),
#  Entry(hash=b'\xb0.*7', name='DATA\\START2.DAT', offset=19088948, size=7864, flags=0),
#  Entry(hash=b'\xb0/*7', name='DATA\\START3.DAT', offset=19096812, size=8032, flags=0),
#  Entry(hash=b'\xb00*7', name='DATA\\START4.DAT', offset=19104844, size=7617, flags=0),
#  Entry(hash=b'\xb01*7', name='DATA\\START5.DAT', offset=19112461, size=20984, flags=0),
#  Entry(hash=b'\xb02*7', name='DATA\\START6.DAT', offset=19133445, size=5221, flags=0),
#  Entry(hash=b'\xb03*7', name='DATA\\START7.DAT', offset=19138666, size=5924, flags=0),
#  Entry(hash=b'\xb04*7', name='DATA\\START8.DAT', offset=19144590, size=6648, flags=0),
#  Entry(hash=b'\xb05*7', name='DATA\\START9.DAT', offset=19151238, size=7633, flags=0),
#  Entry(hash=b'\xc16\x1f7', name='DATA\\TERRHI.DAT', offset=19158871, size=65535, flags=0),
#  Entry(hash=b"7\x1c'!", name='DATA\\TERRMAP.DAT', offset=19224406, size=65535, flags=0),
#  Entry(hash=b'\x1d/\x1f"', name='DATA\\TEXSET0.DAT', offset=19289941, size=20, flags=0),
#  Entry(hash=b'\x17\x1d\x92\x89', name='DATA\\UNITSLIST.DAT', offset=19289961, size=31938, flags=0),
#  Entry(hash=b'09$\x1b', name='DATA\\UPGLIST.DAT', offset=19321899, size=275481, flags=0),
#  Entry(hash=b'.U\x91\x8b', name='DAU.GP', offset=19597380, size=82040, flags=0),
#  Entry(hash=b'.U\x85\x91', name='DAU.MD', offset=19679420, size=3120, flags=0),
#  Entry(hash=b'\x8b\x83\x9b\xd9', name='DAUDEZ.GP', offset=19682540, size=22059, flags=0),
#  Entry(hash=b'{\xec\xdb\xd3', name='DENMARK.NDS', offset=19704599, size=62410, flags=0),
#  Entry(hash=b'\xda-1\n', name='DENMARK_BLD.BMP', offset=19767009, size=735480, flags=0),
#  Entry(hash=b'G{oO', name='DESCRIPTION\\ADET.MD', offset=20502489, size=152, flags=0),
#  Entry(hash=b'!3mn', name='DESCRIPTION\\AKA.MD', offset=20502641, size=152, flags=0),
#  Entry(hash=b'x\x80Wv', name='DESCRIPTION\\AKAAU.MD', offset=20502793, size=152, flags=0),
#  Entry(hash=b'y\x80Wb', name='DESCRIPTION\\AKABA.MD', offset=20502945, size=152, flags=0),
#  Entry(hash=b'y\x80Ws', name='DESCRIPTION\\AKABR.MD', offset=20503097, size=152, flags=0),
#  Entry(hash=b'{\x80Wb', name='DESCRIPTION\\AKADA.MD', offset=20503249, size=152, flags=0),
#  Entry(hash=b'}\x80Ws', name='DESCRIPTION\\AKAFR.MD', offset=20503401, size=152, flags=0),
#  Entry(hash=b'~\x80Wf', name='DESCRIPTION\\AKAGE.MD', offset=20503553, size=152, flags=0),
#  Entry(hash=b'\x7f\x80Wp', name='DESCRIPTION\\AKAHO.MD', offset=20503705, size=152, flags=0),
#  Entry(hash=b'\x87\x80Wj', name='DESCRIPTION\\AKAPI.MD', offset=20503857, size=152, flags=0),
#  Entry(hash=b'\x87\x80Wm', name='DESCRIPTION\\AKAPL.MD', offset=20504009, size=152, flags=0),
#  Entry(hash=b'\x87\x80Wp', name='DESCRIPTION\\AKAPO.MD', offset=20504161, size=152, flags=0),
#  Entry(hash=b'EwvO', name='DESCRIPTION\\AKAR.MD', offset=20504313, size=152, flags=0),
#  Entry(hash=b'\x8a\x80Wb', name='DESCRIPTION\\AKASA.MD', offset=20504465, size=152, flags=0),
#  Entry(hash=b'\x8a\x80Wq', name='DESCRIPTION\\AKASP.MD', offset=20504617, size=152, flags=0),
#  Entry(hash=b'\x8a\x80Ww', name='DESCRIPTION\\AKASV.MD', offset=20504769, size=152, flags=0),
#  Entry(hash=b'HwvO', name='DESCRIPTION\\AKAU.MD', offset=20504921, size=152, flags=0),
#  Entry(hash=b'\x8d\x80Wf', name='DESCRIPTION\\AKAVE.MD', offset=20505073, size=152, flags=0),
#  Entry(hash=b'!7mn', name='DESCRIPTION\\AKE.MD', offset=20505225, size=152, flags=0),
#  Entry(hash=b'Gz}O', name='DESCRIPTION\\ARDT.MD', offset=20505377, size=1, flags=0),
#  Entry(hash=b'!Ftn', name='DESCRIPTION\\ART.MD', offset=20505378, size=50, flags=0),
#  Entry(hash=b'x\x93^v', name='DESCRIPTION\\ARTAU.MD', offset=20505428, size=50, flags=0),
#  Entry(hash=b'y\x93^b', name='DESCRIPTION\\ARTBA.MD', offset=20505478, size=50, flags=0),
#  Entry(hash=b'y\x93^s', name='DESCRIPTION\\ARTBR.MD', offset=20505528, size=50, flags=0),
#  Entry(hash=b'{\x93^b', name='DESCRIPTION\\ARTDA.MD', offset=20505578, size=50, flags=0),
#  Entry(hash=b'}\x93^s', name='DESCRIPTION\\ARTFR.MD', offset=20505628, size=50, flags=0),
#  Entry(hash=b'~\x93^f', name='DESCRIPTION\\ARTGE.MD', offset=20505678, size=50, flags=0),
#  Entry(hash=b'\x7f\x93^p', name='DESCRIPTION\\ARTHO.MD', offset=20505728, size=50, flags=0),
#  Entry(hash=b'\x87\x93^j', name='DESCRIPTION\\ARTPI.MD', offset=20505778, size=50, flags=0),
#  Entry(hash=b'\x87\x93^m', name='DESCRIPTION\\ARTPL.MD', offset=20505828, size=50, flags=0),
#  Entry(hash=b'\x87\x93^p', name='DESCRIPTION\\ARTPO.MD', offset=20505878, size=50, flags=0),
#  Entry(hash=b'\x89\x93^v', name='DESCRIPTION\\ARTRU.MD', offset=20505928, size=50, flags=0),
#  Entry(hash=b'\x8a\x93^b', name='DESCRIPTION\\ARTSA.MD', offset=20505978, size=50, flags=0),
#  Entry(hash=b'\x8a\x93^q', name='DESCRIPTION\\ARTSP.MD', offset=20506028, size=50, flags=0),
#  Entry(hash=b'\x8a\x93^w', name='DESCRIPTION\\ARTSV.MD', offset=20506078, size=50, flags=0),
#  Entry(hash=b'G\x8a}O', name='DESCRIPTION\\ARTT.MD', offset=20506128, size=0, flags=0),
#  Entry(hash=b'H\x8a}O', name='DESCRIPTION\\ARTU.MD', offset=20506128, size=50, flags=0),
#  Entry(hash=b'\x8d\x93^f', name='DESCRIPTION\\ARTVE.MD', offset=20506178, size=50, flags=0),
#  Entry(hash=b'\x9flc\xa7', name='DESCRIPTION\\ATL_B1.MD', offset=20506228, size=10, flags=0),
#  Entry(hash=b'!#co', name='DESCRIPTION\\BA1.MD', offset=20506238, size=93, flags=0),
#  Entry(hash=b'!7co', name='DESCRIPTION\\BAE.MD', offset=20506331, size=93, flags=0),
#  Entry(hash=b'!Dco', name='DESCRIPTION\\BAR.MD', offset=20506424, size=93, flags=0),
#  Entry(hash=b'!Eco', name='DESCRIPTION\\BAS.MD', offset=20506517, size=284, flags=0),
#  Entry(hash=b'!Fco', name='DESCRIPTION\\BAT.MD', offset=20506801, size=95, flags=0),
#  Entry(hash=b'\x8c\x80S|', name='DESCRIPTION\\BGAUZ.MD', offset=20506896, size=2, flags=0),
#  Entry(hash=b'\x95aW\xc0', name='DESCRIPTION\\BGAUZ2.MD', offset=20506898, size=2, flags=0),
#  Entry(hash=b'!Fto', name='DESCRIPTION\\BRT.MD', offset=20506900, size=73, flags=0),
#  Entry(hash=b'!;wo', name='DESCRIPTION\\BUI.MD', offset=20506973, size=6, flags=0),
#  Entry(hash=b'!>cp', name='DESCRIPTION\\CAL.MD', offset=20506979, size=165, flags=0),
#  Entry(hash=b'!Gcp', name='DESCRIPTION\\CAU.MD', offset=20507144, size=268, flags=0),
#  Entry(hash=b'!3fp', name='DESCRIPTION\\CDA.MD', offset=20507412, size=268, flags=0),
#  Entry(hash=b'!4gp', name='DESCRIPTION\\CEB.MD', offset=20507680, size=79, flags=0),
#  Entry(hash=b'4xpQ', name='DESCRIPTION\\CEBA.MD', offset=20507759, size=268, flags=0),
#  Entry(hash=b'!8gp', name='DESCRIPTION\\CEF.MD', offset=20508027, size=268, flags=0),
#  Entry(hash=b'%|pQ', name='DESCRIPTION\\CEF2.MD', offset=20508295, size=268, flags=0),
#  Entry(hash=b'!:gp', name='DESCRIPTION\\CEH.MD', offset=20508563, size=268, flags=0),
#  Entry(hash=b'!;gp', name='DESCRIPTION\\CEI.MD', offset=20508831, size=268, flags=0),
#  Entry(hash=b'!Bgp', name='DESCRIPTION\\CEP.MD', offset=20509099, size=268, flags=0),
#  Entry(hash=b'!Dgp', name='DESCRIPTION\\CER.MD', offset=20509367, size=18, flags=0),
#  Entry(hash=b'H\x88pQ', name='DESCRIPTION\\CERU.MD', offset=20509385, size=18, flags=0),
#  Entry(hash=b'!Egp', name='DESCRIPTION\\CES.MD', offset=20509403, size=268, flags=0),
#  Entry(hash=b'!Fgp', name='DESCRIPTION\\CET.MD', offset=20509671, size=165, flags=0),
#  Entry(hash=b'!Hgp', name='DESCRIPTION\\CEV.MD', offset=20509836, size=268, flags=0),
#  Entry(hash=b'!>rp', name='DESCRIPTION\\CPL.MD', offset=20510104, size=268, flags=0),
#  Entry(hash=b'!Arp', name='DESCRIPTION\\CPO.MD', offset=20510372, size=268, flags=0),
#  Entry(hash=b'!Btp', name='DESCRIPTION\\CRP.MD', offset=20510640, size=1, flags=0),
#  Entry(hash=b'!Iup', name='DESCRIPTION\\CSW.MD', offset=20510641, size=268, flags=0),
#  Entry(hash=b'!Dwp', name='DESCRIPTION\\CUR.MD', offset=20510909, size=165, flags=0),
#  Entry(hash=b'!>cq', name='DESCRIPTION\\DAL.MD', offset=20511074, size=64, flags=0),
#  Entry(hash=b'!Gcq', name='DESCRIPTION\\DAU.MD', offset=20511138, size=64, flags=0),
#  Entry(hash=b'!Bkq', name='DESCRIPTION\\DIP.MD', offset=20511202, size=83, flags=0),
#  Entry(hash=b'x\x8fUy', name='DESCRIPTION\\DIPAU.MD', offset=20511285, size=83, flags=0),
#  Entry(hash=b'y\x8fUe', name='DESCRIPTION\\DIPBA.MD', offset=20511368, size=83, flags=0),
#  Entry(hash=b'y\x8fUv', name='DESCRIPTION\\DIPBR.MD', offset=20511451, size=83, flags=0),
#  Entry(hash=b'{\x8fUe', name='DESCRIPTION\\DIPDA.MD', offset=20511534, size=83, flags=0),
#  Entry(hash=b'}\x8fUv', name='DESCRIPTION\\DIPFR.MD', offset=20511617, size=83, flags=0),
#  Entry(hash=b'~\x8fUi', name='DESCRIPTION\\DIPGE.MD', offset=20511700, size=83, flags=0),
#  Entry(hash=b'\x7f\x8fUs', name='DESCRIPTION\\DIPHO.MD', offset=20511783, size=83, flags=0),
#  Entry(hash=b'\x87\x8fUm', name='DESCRIPTION\\DIPPI.MD', offset=20511866, size=83, flags=0),
#  Entry(hash=b'\x87\x8fUp', name='DESCRIPTION\\DIPPL.MD', offset=20511949, size=83, flags=0),
#  Entry(hash=b'\x87\x8fUs', name='DESCRIPTION\\DIPPO.MD', offset=20512032, size=83, flags=0),
#  Entry(hash=b'E\x86tR', name='DESCRIPTION\\DIPR.MD', offset=20512115, size=83, flags=0),
# ...
#  Entry(hash=b'\x88gm\xcc', name='DESCRIPTION\\VNGHRA.MD', offset=20543692, size=18, flags=0),
#  Entry(hash=b'\x8bgc\xab', name='DESCRIPTION\\VNGK17.MD', offset=20543710, size=126, flags=0),
#  Entry(hash=b'\x8bgd\xab', name='DESCRIPTION\\VNGK18.MD', offset=20543836, size=126, flags=0),
#  Entry(hash=b'\x8bgz\xc9', name='DESCRIPTION\\VNGKON.MD', offset=20543962, size=135, flags=0),
#  Entry(hash=b'l}\xbe\xd3', name='DESCRIPTION\\VNGKPND.MD', offset=20544097, size=125, flags=0),
#  Entry(hash=b'\x8bg\x86\xcf', name='DESCRIPTION\\VNGKUZ.MD', offset=20544222, size=79, flags=0),
#  Entry(hash=b'\x8bgx\xd0', name='DESCRIPTION\\VNGKVL.MD', offset=20544301, size=133, flags=0),
#  Entry(hash=b'\x90gp\xc8', name='DESCRIPTION\\VNGPND.MD', offset=20544434, size=114, flags=0),
#  Entry(hash=b'\x93g~\xbf', name='DESCRIPTION\\VNGSER.MD', offset=20544548, size=186, flags=0),
#  Entry(hash=b'l\x8f\xae\xe3', name='DESCRIPTION\\WAKK_KR.MD', offset=20544734, size=0, flags=0),
#  Entry(hash=b'm\x94\xa8\xe3', name='DESCRIPTION\\WALL_EV.MD', offset=20544734, size=191, flags=0),
#  Entry(hash=b'm\x90\xae\xe3', name='DESCRIPTION\\WALL_KR.MD', offset=20544925, size=191, flags=0),
#  Entry(hash=b'm\x93\xb7\xe3', name='DESCRIPTION\\WALL_TU.MD', offset=20545116, size=191, flags=0),
#  Entry(hash=b'\x91\xcd\xc1\xc4', name='DESCRIPTION\\WALL_UKR.MD', offset=20545307, size=123, flags=0),
#  Entry(hash=b'!:c\x86', name='DESCRIPTION\\YAH.MD', offset=20545430, size=116, flags=0),
#  Entry(hash=b'\x8b\x87M\x8e', name='DESCRIPTION\\YAHTU.MD', offset=20545546, size=252, flags=0),
#  Entry(hash=b'\x83\xf8\xbe\xb7', name='DFIRE1_1.GP', offset=20545798, size=28852, flags=0),
#  Entry(hash=b'\x84\xf8\xbe\xb7', name='DFIRE1_2.GP', offset=20574650, size=45620, flags=0),
#  Entry(hash=b'\xa1\x8du\xcf', name='DGFOG.GRD', offset=20620270, size=40960, flags=0),
#  Entry(hash=b'1\x9d\x90r', name='DIM1.GP', offset=20661230, size=33456, flags=0),
#  Entry(hash=b'\x83\x94wv', name='DIM32.GP', offset=20694686, size=1137744, flags=0),
#  Entry(hash=b'\x91\x94w\x9b', name='DIMAW.GP', offset=21832430, size=246231, flags=0),
#  Entry(hash=b'\x94{\x9b\xe3', name='DIMMOR.GP', offset=22078661, size=720474, flags=0),
#  Entry(hash=b'\x91\x97w\x99', name='DIPAU.GP', offset=22799135, size=236892, flags=0),
#  Entry(hash=b'\x85\x9dw\x99', name='DIPAU.MD', offset=23036027, size=6037, flags=0),
#  Entry(hash=b'\x9b\xe5\xd4\xc7', name='DIPAUDEZ.GP', offset=23042064, size=61936, flags=0),
#  Entry(hash=b'\x92\x97w\x85', name='DIPBA.GP', offset=23104000, size=115415, flags=0),
#  Entry(hash=b'\x86\x9dw\x85', name='DIPBA.MD', offset=23219415, size=3328, flags=0),
#  Entry(hash=b'\x9c\xe5\xd4\xb3', name='DIPBADEZ.GP', offset=23222743, size=33523, flags=0),
#  Entry(hash=b'\x92\x97w\x96', name='DIPBR.GP', offset=23256266, size=101526, flags=0),
#  Entry(hash=b'\x86\x9dw\x96', name='DIPBR.MD', offset=23357792, size=3942, flags=0),
#  Entry(hash=b'\x9c\xe5\xd4\xc4', name='DIPBRDEZ.GP', offset=23361734, size=34750, flags=0),
#  Entry(hash=b'\x94\x97w\x85', name='DIPDA.GP', offset=23396484, size=193239, flags=0),
#  Entry(hash=b'\x88\x9dw\x85', name='DIPDA.MD', offset=23589723, size=5227, flags=0),
#  Entry(hash=b'\x9e\xe5\xd4\xb3', name='DIPDADEZ.GP', offset=23594950, size=47260, flags=0),
#  Entry(hash=b'\x96\x97w\x96', name='DIPFR.GP', offset=23642210, size=113189, flags=0),
#  Entry(hash=b'\x8a\x9dw\x96', name='DIPFR.MD', offset=23755399, size=3810, flags=0),
#  Entry(hash=b'\xa0\xe5\xd4\xc4', name='DIPFRDEZ.GP', offset=23759209, size=37267, flags=0),
#  Entry(hash=b'\x97\x97w\x89', name='DIPGE.GP', offset=23796476, size=138615, flags=0),
#  Entry(hash=b'\x8b\x9dw\x89', name='DIPGE.MD', offset=23935091, size=4091, flags=0),
#  Entry(hash=b'\xa1\xe5\xd4\xb7', name='DIPGEDEZ.GP', offset=23939182, size=45384, flags=0),
#  Entry(hash=b'\x98\x97w\x93', name='DIPHO.GP', offset=23984566, size=143988, flags=0),
#  Entry(hash=b'\x8c\x9dw\x93', name='DIPHO.MD', offset=24128554, size=3750, flags=0),
#  Entry(hash=b'\xa2\xe5\xd4\xc1', name='DIPHODEZ.GP', offset=24132304, size=51144, flags=0),
#  Entry(hash=b'\xa0\x97w\x8d', name='DIPPI.GP', offset=24183448, size=161798, flags=0),
#  Entry(hash=b'\x94\x9dw\x8d', name='DIPPI.MD', offset=24345246, size=4641, flags=0),
#  Entry(hash=b'\xaa\xe5\xd4\xbb', name='DIPPIDEZ.GP', offset=24349887, size=41999, flags=0),
#  Entry(hash=b'\xa0\x97w\x90', name='DIPPL.GP', offset=24391886, size=121125, flags=0),
#  Entry(hash=b'\x94\x9dw\x90', name='DIPPL.MD', offset=24513011, size=4018, flags=0),
#  Entry(hash=b'\xaa\xe5\xd4\xbe', name='DIPPLDEZ.GP', offset=24517029, size=33054, flags=0),
#  Entry(hash=b'\xa0\x97w\x93', name='DIPPO.GP', offset=24550083, size=174883, flags=0),
#  Entry(hash=b'\x94\x9dw\x93', name='DIPPO.MD', offset=24724966, size=5012, flags=0),
#  Entry(hash=b'\xaa\xe5\xd4\xc1', name='DIPPODEZ.GP', offset=24729978, size=58774, flags=0),
#  Entry(hash=b'R\x94\x96r', name='DIPR.MD', offset=24788752, size=5395, flags=0),
#  Entry(hash=b'\xa2\x97w\x99', name='DIPRU.GP', offset=24794147, size=194865, flags=0),
#  Entry(hash=b'\xac\xe5\xd4\xc7', name='DIPRUDEZ.GP', offset=24989012, size=44158, flags=0),
#  Entry(hash=b'\xa3\x97w\x85', name='DIPSA.GP', offset=25033170, size=118395, flags=0),
#  Entry(hash=b'\x97\x9dw\x85', name='DIPSA.MD', offset=25151565, size=3997, flags=0),
#  Entry(hash=b'\xad\xe5\xd4\xb3', name='DIPSADEZ.GP', offset=25155562, size=41352, flags=0),
#  Entry(hash=b'\xa3\x97w\x94', name='DIPSP.GP', offset=25196914, size=160887, flags=0),
#  Entry(hash=b'\x97\x9dw\x94', name='DIPSP.MD', offset=25357801, size=5134, flags=0),
#  Entry(hash=b'\xad\xe5\xd4\xc2', name='DIPSPDEZ.GP', offset=25362935, size=42131, flags=0),
#  Entry(hash=b'\xa3\x97w\x9a', name='DIPSV.GP', offset=25405066, size=116256, flags=0),
#  Entry(hash=b'\x97\x9dw\x9a', name='DIPSV.MD', offset=25521322, size=3573, flags=0),
#  Entry(hash=b'\xad\xe5\xd4\xc8', name='DIPSVDEZ.GP', offset=25524895, size=38865, flags=0),
#  Entry(hash=b'T\xa0\x90r', name='DIPT.GP', offset=25563760, size=155008, flags=0),
#  Entry(hash=b'T\x94\x96r', name='DIPT.MD', offset=25718768, size=5086, flags=0),
#  Entry(hash=b'\x82\xaa\xde\xcf', name='DIPTDEZ.GP', offset=25723854, size=41157, flags=0),
#  Entry(hash=b'U\xa0\x90r', name='DIPU.GP', offset=25765011, size=109246, flags=0),
#  Entry(hash=b'U\x94\x96r', name='DIPU.MD', offset=25874257, size=4621, flags=0),
#  Entry(hash=b'\x83\xaa\xde\xcf', name='DIPUDEZ.GP', offset=25878878, size=31095, flags=0),
#  Entry(hash=b'\xa6\x97w\x89', name='DIPVE.GP', offset=25909973, size=153412, flags=0),
#  Entry(hash=b'\x9a\x9dw\x89', name='DIPVE.MD', offset=26063385, size=4130, flags=0),
#  Entry(hash=b'\xb0\xe5\xd4\xb7', name='DIPVEDEZ.GP', offset=26067515, size=42924, flags=0),
#  Entry(hash=b'P.\x99\x85', name='DM.PAL', offset=26110439, size=768, flags=0),
#  Entry(hash=b'.\xa3\x8e\x94', name='DMW.PAL', offset=26111207, size=768, flags=0),
#  Entry(hash=b'}\x98\x9dr', name='DMW1.PAL', offset=26111975, size=768, flags=0),
#  Entry(hash=b'.B\x93\x91', name='DOB.MD', offset=26112743, size=3163, flags=0),
#  Entry(hash=b'A\x92\x96r', name='DOBA.GP', offset=26115906, size=86275, flags=0),
#  Entry(hash=b'A\x86\x9cr', name='DOBA.MD', offset=26202181, size=4037, flags=0),
#  Entry(hash=b'o\x9c\xe4\xcf', name='DOBADEZ.GP', offset=26206218, size=31503, flags=0),
#  Entry(hash=b'\x92\x89}\x96', name='DOBBR.GP', offset=26237721, size=56038, flags=0),
#  Entry(hash=b'\x9c\xd7\xda\xc4', name='DOBBRDEZ.GP', offset=26293759, size=22558, flags=0),
#  Entry(hash=b'A\x94\x96r', name='DODA.GP', offset=26316317, size=55760, flags=0),
#  Entry(hash=b'A\x88\x9cr', name='DODA.MD', offset=26372077, size=2896, flags=0),
#  Entry(hash=b'o\x9e\xe4\xcf', name='DODADEZ.GP', offset=26374973, size=18169, flags=0),
#  Entry(hash=b'2\x96\x96r', name='DOF2.GP', offset=26393142, size=35489, flags=0),
#  Entry(hash=b'2\x8a\x9cr', name='DOF2.MD', offset=26428631, size=2504, flags=0),
#  Entry(hash=b'`\xa0\xe4\xcf', name='DOF2DEZ.GP', offset=26431135, size=11934, flags=0),
#  Entry(hash=b'.H\x9f\x8b', name='DOH.GP', offset=26443069, size=68190, flags=0),
#  Entry(hash=b'\x8bv\xa9\xd9', name='DOHDEZ.GP', offset=26511259, size=22195, flags=0),
#  Entry(hash=b'.I\x9f\x8b', name='DOI.GP', offset=26533454, size=77759, flags=0),
#  Entry(hash=b'.I\x93\x91', name='DOI.MD', offset=26611213, size=3411, flags=0),
#  Entry(hash=b'\x8bw\xa9\xd9', name='DOIDEZ.GP', offset=26614624, size=25958, flags=0),
#  Entry(hash=b'.P\x9f\x8b', name='DOP.GP', offset=26640582, size=65300, flags=0),
#  Entry(hash=b'.P\x93\x91', name='DOP.MD', offset=26705882, size=3114, flags=0),
#  Entry(hash=b'\x8b~\xa9\xd9', name='DOPDEZ.GP', offset=26708996, size=21640, flags=0),
#  Entry(hash=b'.S\x9f\x8b', name='DOS.GP', offset=26730636, size=79383, flags=0),
#  Entry(hash=b'.S\x93\x91', name='DOS.MD', offset=26810019, size=3153, flags=0),
#  Entry(hash=b'\x8b\x81\xa9\xd9', name='DOSDEZ.GP', offset=26813172, size=21461, flags=0),
#  Entry(hash=b'.T\x9f\x8b', name='DOT.GP', offset=26834633, size=36975, flags=0),
#  Entry(hash=b'.T\x93\x91', name='DOT.MD', offset=26871608, size=2394, flags=0),
#  Entry(hash=b'\x8b\x82\xa9\xd9', name='DOTDEZ.GP', offset=26874002, size=11946, flags=0),
#  Entry(hash=b'.V\x9f\x8b', name='DOV.GP', offset=26885948, size=50609, flags=0),
#  Entry(hash=b'.V\x93\x91', name='DOV.MD', offset=26936557, size=2481, flags=0),
#  Entry(hash=b'\x8b\x84\xa9\xd9', name='DOVDEZ.GP', offset=26939038, size=18365, flags=0),
#  Entry(hash=b'.L\xa0\x8b', name='DPL.GP', offset=26957403, size=72950, flags=0),
#  Entry(hash=b'.L\x94\x91', name='DPL.MD', offset=27030353, size=3533, flags=0),
#  Entry(hash=b'\x8bz\xaa\xd9', name='DPLDEZ.GP', offset=27033886, size=23164, flags=0),
#  Entry(hash=b'.O\xa0\x8b', name='DPO.GP', offset=27057050, size=69093, flags=0),
#  Entry(hash=b'.O\x94\x91', name='DPO.MD', offset=27126143, size=3225, flags=0),
#  Entry(hash=b'\x8b}\xaa\xd9', name='DPODEZ.GP', offset=27129368, size=28425, flags=0),
#  Entry(hash=b'.R\xa0\x8b', name='DPR.GP', offset=27157793, size=67987, flags=0),
#  Entry(hash=b'.R\x94\x91', name='DPR.MD', offset=27225780, size=3006, flags=0),
#  Entry(hash=b'\x8b\x80\xaa\xd9', name='DPRDEZ.GP', offset=27228786, size=18866, flags=0),
#  Entry(hash=b'.2\x96\x91', name='DR2.MD', offset=27247652, size=1345, flags=0),
#  Entry(hash=b'\x91`\xa2\xd1', name='DR2DIP.MD', offset=27248997, size=1170, flags=0),
#  Entry(hash=b'G\x82\x99r', name='DR2G.GP', offset=27250167, size=304857, flags=0),
#  Entry(hash=b'H\x82\x99r', name='DR2H.GP', offset=27555024, size=427985, flags=0),
#  Entry(hash=b'S\x82\x99r', name='DR2S.GP', offset=27983009, size=309424, flags=0),
#  Entry(hash=b'V\x82\x99r', name='DR2V.GP', offset=28292433, size=719080, flags=0),
#  Entry(hash=b'.A\x96\x91', name='DRA.MD', offset=29011513, size=1163, flags=0),
#  Entry(hash=b'G\x91\x99r', name='DRAG.GP', offset=29012676, size=270424, flags=0),
#  Entry(hash=b'H\x91\x99r', name='DRAH.GP', offset=29283100, size=384589, flags=0),
#  Entry(hash=b'S\x91\x99r', name='DRAS.GP', offset=29667689, size=275155, flags=0),
#  Entry(hash=b'V\x91\x99r', name='DRAV.GP', offset=29942844, size=658040, flags=0),
#  Entry(hash=b'.F\x96\x91', name='DRF.MD', offset=30600884, size=1380, flags=0),
#  Entry(hash=b'G\x96\x99r', name='DRFG.GP', offset=30602264, size=295419, flags=0),
#  Entry(hash=b'H\x96\x99r', name='DRFH.GP', offset=30897683, size=426245, flags=0),
#  Entry(hash=b'S\x96\x99r', name='DRFS.GP', offset=31323928, size=364520, flags=0),
#  Entry(hash=b'V\x96\x99r', name='DRFV.GP', offset=31688448, size=713539, flags=0),
#  Entry(hash=b'.W\xa3\x8b', name='DSW.GP', offset=32401987, size=54113, flags=0),
#  Entry(hash=b'.W\x97\x91', name='DSW.MD', offset=32456100, size=2964, flags=0),
#  Entry(hash=b'\x8b\x85\xad\xd9', name='DSWDEZ.GP', offset=32459064, size=18172, flags=0),
#  Entry(hash=b'\xa4\xa5\xa9r', name='DUMP.TXT', offset=32477236, size=0, flags=0),
#  Entry(hash=b'|\xfc\xe8\xe8', name='ECONOMY.TXT', offset=32477236, size=805, flags=0),
#  Entry(hash=b'z\xde\xe0\xd4', name='ENGLAND.NDS', offset=32478041, size=66319, flags=0),
#  Entry(hash=b'\xd9\x1f6\x0b', name='ENGLAND_BLD.BMP', offset=32544360, size=735480, flags=0),
#  Entry(hash=b'.S\x92\x92', name='ENS.MD', offset=33279840, size=1548, flags=0),
#  Entry(hash=b'B\xa3\x95s', name='ENSB.GP', offset=33281388, size=159535, flags=0),
#  Entry(hash=b'G\xa3\x95s', name='ENSG.GP', offset=33440923, size=163353, flags=0),
#  Entry(hash=b'H\xa3\x95s', name='ENSH.GP', offset=33604276, size=174652, flags=0),
#  Entry(hash=b'P\xa3\x95s', name='ENSP.GP', offset=33778928, size=150451, flags=0),
#  Entry(hash=b'V\xa3\x95s', name='ENSV.GP', offset=33929379, size=153683, flags=0),
#  Entry(hash=b'.V\x92\x92', name='ENV.MD', offset=34083062, size=542, flags=0),
#  Entry(hash=b'G\xa6\x95s', name='ENVG.GP', offset=34083604, size=184351, flags=0),
#  Entry(hash=b'H\xa6\x95s', name='ENVH.GP', offset=34267955, size=217397, flags=0),
#  Entry(hash=b'S\xa6\x95s', name='ENVS.GP', offset=34485352, size=36756, flags=0),
#  Entry(hash=b'T\xa6\x95s', name='ENVT.GP', offset=34522108, size=73005, flags=0),
#  Entry(hash=b'V\xa6\x95s', name='ENVV.GP', offset=34595113, size=180208, flags=0),
#  Entry(hash=b'.D\x99\x92', name='EUD.MD', offset=34775321, size=3237, flags=0),
#  Entry(hash=b'.R\xa6\x8c', name='EVR.GP', offset=34778558, size=176436, flags=0),
#  Entry(hash=b'.R\x9a\x92', name='EVR.MD', offset=34954994, size=5039, flags=0),
#  Entry(hash=b'\x8b\x80\xb0\xda', name='EVRDEZ.GP', offset=34960033, size=51295, flags=0),
#  Entry(hash=b'PG.F', name='F.GP', offset=35011328, size=28083, flags=0),
#  Entry(hash=b'\x9c\x82\x83t', name='F16Y.RLC', offset=35039411, size=31434, flags=0),
#  Entry(hash=b'\xa5\x88_\xba', name='F16Y1.RLC', offset=35070845, size=31406, flags=0),
#  Entry(hash=b'G.2\x96', name='F2.GP', offset=35102251, size=102930, flags=0),
#  Entry(hash=b'G.3\x96', name='F3.GP', offset=35205181, size=12063, flags=0),
#  Entry(hash=b'\x98\x97w\xcd', name='FIELD.RLC', offset=35217244, size=106942, flags=0),
#  Entry(hash=b'\x99sz\xce', name='FIELD1.MD', offset=35324186, size=123, flags=0),
#  Entry(hash=b'\x9es\xdf\xd6', name='FIELDS.RLC', offset=35324309, size=2914, flags=0),
#  Entry(hash=b'\xed\xf2\xde\xc0', name='FILELIST.LST', offset=35327223, size=14177, flags=0),
#  Entry(hash=b'G\x91\x93t', name='FLAG.GP', offset=35341400, size=5905, flags=0),
#  Entry(hash=b'.G\x90\x93', name='FLG.MD', offset=35347305, size=598, flags=0),
#  Entry(hash=b'G\x97\x93t', name='FLGG.GP', offset=35347903, size=117538, flags=0),
#  Entry(hash=b'H\x97\x93t', name='FLGH.GP', offset=35465441, size=211496, flags=0),
#  Entry(hash=b'S\x97\x93t', name='FLGS.GP', offset=35676937, size=598832, flags=0),
#  Entry(hash=b's}\xa0t', name='FN10.RLC', offset=36275769, size=15399, flags=0),
#  Entry(hash=b'.8\x9e\x8d', name='FN8.GP', offset=36291168, size=13289, flags=0),
#  Entry(hash=b'\x9co\xea\xcd', name='FRANCE.NDS', offset=36304457, size=69093, flags=0),
#  Entry(hash=b'\xd2\xce+#', name='FRANCE_BLD.BMP', offset=36373550, size=735480, flags=0),
#  Entry(hash=b'G\x95\x99t', name='FREG.GP', offset=37109030, size=854415, flags=0),
#  Entry(hash=b'G\x89\x9ft', name='FREG.MD', offset=37963445, size=1834, flags=0),
#  Entry(hash=b'u\x8e\xf7\xcf', name='FREGBUI.GP', offset=37965279, size=66808, flags=0),
#  Entry(hash=b'u\x9f\xe7\xd1', name='FREGDEZ.GP', offset=38032087, size=31428, flags=0),
#  Entry(hash=b'.N\xa2\x8d', name='FRN.GP', offset=38063515, size=1898067, flags=0),
#  Entry(hash=b'.N\x96\x93', name='FRN.MD', offset=39961582, size=1875, flags=0),
#  Entry(hash=b'\x89|\x9b\xeb', name='FRNBUI.GP', offset=39963457, size=60632, flags=0),
#  Entry(hash=b'\x8b|\xac\xdb', name='FRNDEZ.GP', offset=40024089, size=35663, flags=0),
#  Entry(hash=b'\xa4}\xcb\xdd', name='FWORK1.RLC', offset=40059752, size=81446, flags=0),
#  Entry(hash=b'\x80\xe5\xd4\xe3', name='FWORK1S.RLC', offset=40141198, size=4446, flags=0),
#  Entry(hash=b'\xa4}\xcc\xdd', name='FWORK2.RLC', offset=40145644, size=86755, flags=0),
#  Entry(hash=b'\x80\xe5\xd5\xe3', name='FWORK2S.RLC', offset=40232399, size=5178, flags=0),
#  Entry(hash=b'\xa4}\xcd\xdd', name='FWORK3.RLC', offset=40237577, size=7877, flags=0),
#  ...]

# %%
entries[-1].offset + entries[-1].size + offset_after_entries, len(data)
# Out:
# (243698958, 243698958)

# %%
def extract_data(e: Entry) -> bytes:
    offset = entry.offset + offset_after_entries
    e_data = bytearray(data[offset: offset + e.size])
    for i in range(len(e_data)):
        e_data[i] = e_data[i] ^ 0x78
    return bytes(e_data)

# %%
for entry in entries:
    path_in_name = entry.name.replace('\\', '/')
    path = f"unpacked/{path_in_name}"
    os.makedirs(os.path.dirname(path), exist_ok=True)
    
    with open(path, "wb") as f:
        f.write(extract_data(entry))

# %%
# bmp header with xor and without
0x3A ^ 0x42, 0x35 ^ 0x4D
# Out:
# (120, 120)
